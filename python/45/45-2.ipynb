# %%
import requests
from bs4 import BeautifulSoup
import xlwt
from lxml import etree
r = requests.get('http://www.douban.com')

# %%
import json
jsonData = '{"a":1,"b":2,"c":3,"d":4,"e":5}'
input = json.loads(jsonData)
print(input)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
# -*- coding:utf-8 -*-
import requests
from bs4 import BeautifulSoup
import xlwt

#获取网页文本信息
def getHTMLText(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except Exception as err:
        print(err)
#通过BeautifulSoup解析网页，提取我们需要的数据
def getData(html):
    soup = BeautifulSoup(html, "html.parser")
    ChatList=soup.find('div',attrs={'id':'list_view'})
    datalist=[]#用于存放提取到全部Chat信息
    #遍历每一条Chat
    for Chat in ChatList.find_all('div',attrs={'class':'item_info_view'}):
        data = []
        #提取Chat标题
        chatTitle=Chat.find('h2',attrs={'class':'info_title user_select_text'}).getText()
        print(chatTitle)
        data.append(chatTitle)    

        #提取订阅人数
        bookingNum = Chat.find('span', attrs={'class': 'info_num'})
        data.append(str(bookingNum.getText()).lstrip())

        #提取作者姓名
        authorName=Chat.find('span',attrs={'class':'author_title'}).getText()
        authorName = authorName.split('·')
        authorName = authorName[0]
        data.append(authorName)

        #提取作者简介
        authorDesc=Chat.find('span',attrs={'class':'author_title'}).getText()
        authorDesc = authorDesc.split('·')
        data.append(authorDesc)
        print(data)
        datalist.append(data)
    return datalist

#保存数据到Excel中
def saveData(datalist,path):
    #标题栏背景色
    styleBlueBkg = xlwt.easyxf('pattern: pattern solid, fore_colour pale_blue; font: bold on;'); # 80% like
    #创建一个工作簿
    book=xlwt.Workbook(encoding='utf-8',style_compression=0)
    #创建一张表
    sheet=book.add_sheet('最热ChatTop20',cell_overwrite_ok=True)
    #标题栏
    titleList=('Chat标题','订阅人数','作者','作者简介')
    #设置第一列尺寸
    first_col = sheet.col(0)
    first_col.width=256*40
    #写入标题栏
    for i in range(0,4):
        sheet.write(0,i,titleList[i], styleBlueBkg)
    #写入Chat信息
    for i in range(0,len(datalist)):
        data=datalist[i]
        for j in range(0,4):
            sheet.write(i+1,j,data[j])
    #保存文件到指定路径
    book.save(path)

#网页地址
chatUrl='http://gitbook.cn/gitchat/columns'
html=getHTMLText(chatUrl)  
datalist=getData(html)
saveData(datalist,str("topChat.xls"))
# Out:
# 数据分析面试剖析 24 讲
# ['数据分析面试剖析 24 讲', '102 人已订阅', '宿永杰 ', ['宿永杰 ', ' 某知名互联网公司数据挖掘工程师']]
# 大规模分布式推荐系统实战
# ['大规模分布式推荐系统实战', '379 人已订阅', '阿星 ', ['阿星 ', ' 资深算法工程师']]
# 大数据 Hadoop 快速入门
# ['大数据 Hadoop 快速入门', '313 人已订阅', '李鹏程 ', ['李鹏程 ', ' 高级数据工程师']]
# 从 0 开始搭建 IoT 平台
# ['从 0 开始搭建 IoT 平台', '1356 人已订阅', '付强 ', ['付强 ', ' 物联网创业者兼 CTO']]
# 案例上手 Python 数据可视化
# ['案例上手 Python 数据可视化', '1938 人已订阅', '齐伟 ', ['齐伟 ', ' Python 大学教材及畅销书作者']]
# RocketMQ 实战与进阶
# ['RocketMQ 实战与进阶', '603 人已订阅', '丁威 ', ['丁威 ', '《RocketMQ 技术内幕》作者；梁勇 ', ' 哈啰出行高级技术专家']]
# 数据仓库原理与实战精讲
# ['数据仓库原理与实战精讲', '645 人已订阅', '李鹏程 ', ['李鹏程 ', ' 高级数据工程师']]
#  深入理解 Sentinel
# [' 深入理解 Sentinel', '464 人已订阅', '吴就业 ', ['吴就业 ', ' 洋葱集团后端架构师']]
# Kubernetes 实践入门指南
# ['Kubernetes 实践入门指南', '524 人已订阅', '肖德时 ', ['肖德时 ', ' 企业级容器技术实践者']]
# Python 全栈 60 天精通之路
# ['Python 全栈 60 天精通之路', '7523 人已订阅', 'zglg ', ['zglg ', ' 某大厂算法工程师；Alicia ', ' 美国顶尖学府 AI 博士后']]
# Python 全栈 450 道常见问题全解析（配套教学）
# ['Python 全栈 450 道常见问题全解析（配套教学）', '2668 人已订阅', 'zglg ', ['zglg ', ' 某大厂算法工程师']]
# 大数据实时计算引擎 Flink 实战与性能优化
# ['大数据实时计算引擎 Flink 实战与性能优化', '2276 人已订阅', 'zhisheng ', ['zhisheng ', ' 监控平台研发工程师']]
# JVM 核心技术 32 讲
# ['JVM 核心技术 32 讲', '1571 人已订阅', '秦金卫 & 任富飞 ', ['秦金卫 & 任富飞 ', ' 多年一线大厂的架构师和技术管理者；10 年一线 JVM 分析调优经验的架构师']]
# 程序员的 MySQL 面试金典
# ['程序员的 MySQL 面试金典', '4189 人已订阅', '老王/张建 ', ['老王/张建 ', ' 10 年资深技术专家']]
# Java 面试全解析：核心知识点与典型面试题
# ['Java 面试全解析：核心知识点与典型面试题', '5088 人已订阅', '老王 ', ['老王 ', ' 资深面试官，阿里云社区认证专家']]
# 数据结构算法面试全解析
# ['数据结构算法面试全解析', '494 人已订阅', '春晨溅雨', ['春晨溅雨', '4 位算法工程师']]
# 详解大数据面试核心知识
# ['详解大数据面试核心知识', '417 人已订阅', '老蒙', ['老蒙', ' Top3 游戏厂商大数据架构师']]
# 分布式中间件实践之路
# ['分布式中间件实践之路', '1853 人已订阅', '应书澜 ', ['应书澜 ', ' 研发专家/面试官']]
# Serverless 技术公开课
# ['Serverless 技术公开课', '998 人已订阅', '阿里巴巴技术团队', ['阿里巴巴技术团队']]
# 机器学习中的数学（全集）
# ['机器学习中的数学（全集）', '582 人已订阅', '张雨萌 ', ['张雨萌 ', ' 清华大学硕士/机器学习书籍作者']]

# %%
# 在豆瓣内获取海报
import requests
from bs4 import BeautifulSoup
import xlwt
import json

downPath = '/Users/du/Downloads/xpath/pic/'
baseUrl = 'https://www.douban.com/j/search_photo?q=邱淑贞&limit=20&start='
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Cookie': 'll="108296"; bid=5yk8By15_aw; douban-fav-remind=1; ap_v=0,6.0; _pk_ses.100001.8cb4=*; _pk_id.100001.8cb4=ec8b9bc37b4a8267.1606659424.3.1606726877.1606724091.',
    'Host': 'www.douban.com',
    'Referer': 'https://www.douban.com/search?cat=1025&q=%E9%82%B1%E6%B7%91%E8%B4%9E',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_16_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}


'''下载图片'''
def download(src, id):
    dir = downPath + str(id) + '.jpg'
    try:
        pic = requests.get(src, timeout=20)
        fp = open(dir, 'wb')
        fp.write(pic.content)
        fp.close()
    except requests.exceptions.ConnectionError:
        print('图片无法下载')

'''for 循环 请求全部的url'''
for i in range(0,200,20):
    url = baseUrl+str(i)
    r = requests.get('https://www.douban.com/j/search_photo?q=邱淑贞&limit=20&start=0',headers=headers) # 得到返回结果
    html = r.text
    response = json.loads(html) # 将JSON格式转换成Python对象
    for image in response['images']:
        print(image['src']) # 查看当前下载的图片网址
        download(image['src'], image['id']) # 下载一张图片
# Out:
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739171.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739229.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764739274.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739328.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739356.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764739536.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764739550.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739568.jpg
# https://img1.doubanio.com/view/photo/photo/public/p764739579.jpg
# https://img2.doubanio.com/view/photo/photo/public/p764739583.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739863.jpg
# https://img2.doubanio.com/view/photo/thumb/public/p764739892.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764739941.jpg
# https://img3.doubanio.com/view/photo/photo/public/p764740041.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740186.jpg
# https://img1.doubanio.com/view/photo/thumb/public/p764740417.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740446.jpg
# https://img9.doubanio.com/view/photo/thumb/public/p764740466.jpg
# https://img3.doubanio.com/view/photo/thumb/public/p764740521.jpg
# https://img9.doubanio.com/view/photo/photo/public/p764740606.jpg

# %%
# XPATH 自动下载
import requests
from bs4 import BeautifulSoup
import xlwt

from selenium import webdriver

# 获取网页信息
def getHTMLText(url,headers):
    try:
        r = requests.get(url,headers)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except Exception as err:
        print(err)

# 通过BeautifulSoup解析网页，提取我们需要的数据
def getData(html):
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)
    list = soup.find('div', attrs={'class':'sc-gqjmRU'})
    datalist = [] # 用于存放提取到全部Chat信息
    # 便利每一条chat
    for item in list.find_all('div', attrs={'class':'sc-bZQynM'}):
        data = []
        # 提取标题
        title=item.find('div', attrs={'class':'title'}).getText()
        data.append(title)
        
        # 提取评价人数
        ratingNum = item.find('span',attrs={'class':'pl'})
        data.append(str(ratingNum.getText()).lstrip())
        
        datalist.append(data)
    return datalist

# 保存数据到Excel中
def saveData(datalist,path):
    
    book.save(path)

# 网页地址
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'zh-CN,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Cookie': 'll="108296"; bid=5yk8By15_aw; douban-fav-remind=1; _vwo_uuid_v2=D1A2FF7C0D139157D1720891778396435|38e03d0bdee142cddb55ddcaf01dca7f; __utmc=30149280; ap_v=0,6.0; __utma=30149280.1750674411.1606877571.1606877571.1606919809.2; __utmz=30149280.1606919809.2.2.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; __gads=ID=82ae38b9c0f6cd34-226c1582f9c40097:T=1606919812:RT=1606919812:S=ALNI_Mb1h3Feev45xrBZuSjclfsoKr3Fww; __utmt=1; __utmb=30149280.1.10.1606919809',
    'Host': 'help.douban.com',
    'Referer': 'https://search.douban.com/movie/subject_search?search_text=%E9%82%B1%E6%B7%91%E8%B4%9E&cat=1002',
    'Sec-Fetch-Dest': 'iframe',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-site',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_16_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
}
BaseUrl = 'https://search.douban.com/movie/subject_search?search_text=%E9%82%B1%E6%B7%91%E8%B4%9E&cat=1002'
html = getHTMLText(BaseUrl,headers)
datalist = getData(html)
print(datalist)
# saveData(datalist,str('movie_qsz.xls'))
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="edge" http-equiv="X-UA-Compatible">
# <meta content="“webkit”" name="“renderer”"/>
# <meta content="always" name="referrer"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://img3.doubanio.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/opensearch" rel="search" title="邱淑贞 - 电影 - 豆瓣搜索" type="application/opensearchdescription+xml"/>
# <title>邱淑贞 - 电影 - 豆瓣搜索</title>
# <meta content="邱淑贞 - 电影 - 豆瓣搜索" name="description"/>
# <link href="https://img3.doubanio.com/f/shire/859dba5cddc7ed1435808cf5a8ddde5792cd6e0c/css/douban.css" rel="stylesheet"/>
# <style>
#       #wrapper { width: 1040px; box-sizing: border-box;}
#       @media (max-width: 1024px) { #wrapper { width: 1000px } }
#     </style>
# <script src="//img3.doubanio.com/dae/staticng/s/search/79ec6251e9fc8a33e73c9b4e026c6dd3f2a3d973/dist/jquery.js"></script>
# <style type="text/css">
#     #root {
#       min-height: 500px;
#     }
#
#     #root > .search-title {
#       font-size: 25px;
#       font-weight: bold;
#       line-height: 1;
#       margin-bottom: 30px;
#       padding: 0;
#       color: #494949;
#     }
#   </style>
# </meta></head>
# <body>
# <link href="//img3.doubanio.com/dae/accounts/resources/19870c3/shire/bundle.css" rel="stylesheet" type="text/css"/>
# <div class="global-nav" id="db-global-nav">
# <div class="bd">
# <div class="top-nav-info">
# <a class="nav-login" href="https://accounts.douban.com/passport/login?source=main" rel="nofollow">登录/注册</a>
# </div>
# <div class="top-nav-doubanapp">
# <a class="lnk-doubanapp" href="https://www.douban.com/doubanapp/app?channel=top-nav">下载豆瓣客户端</a>
# <div id="doubanapp-tip">
# <a class="tip-link" href="https://www.douban.com/doubanapp/app?channel=qipao">豆瓣 <span class="version">6.0</span> 全新发布</a>
# <a class="tip-close" href="javascript: void 0;">×</a>
# </div>
# <div class="more-items" id="top-nav-appintro">
# <p class="appintro-title">豆瓣</p>
# <p class="qrcode">扫码直接下载</p>
# <div class="download">
# <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=iOS">iPhone</a>
# <span>·</span>
# <a class="download-android" href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=Android">Android</a>
# </div>
# </div>
# </div>
# <div class="global-nav-items">
# <ul>
# <li class="on">
# <a data-moreurl-dict='{"from":"top-nav-click-main","uid":"0"}' href="https://www.douban.com">豆瓣</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-book","uid":"0"}' href="https://book.douban.com" target="_blank">读书</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-movie","uid":"0"}' href="https://movie.douban.com" target="_blank">电影</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-music","uid":"0"}' href="https://music.douban.com" target="_blank">音乐</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-location","uid":"0"}' href="https://www.douban.com/location" target="_blank">同城</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-group","uid":"0"}' href="https://www.douban.com/group" target="_blank">小组</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-read","uid":"0"}' href="https://read.douban.com/?dcs=top-nav&amp;dcm=douban" target="_blank">阅读</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-fm","uid":"0"}' href="https://douban.fm/?from_=shire_top_nav" target="_blank">FM</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-time","uid":"0"}' href="https://time.douban.com/?dt_time_source=douban-web_top_nav" target="_blank">时间</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-market","uid":"0"}' href="https://market.douban.com/?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank">豆品</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/19870c3/shire/bundle.js"></script>
# <link href="//img3.doubanio.com/dae/accounts/resources/19870c3/movie/bundle.css" rel="stylesheet" type="text/css"/>
# <div class="nav" id="db-nav-movie">
# <div class="nav-wrap">
# <div class="nav-primary">
# <div class="nav-logo">
# <a href="https://movie.douban.com">豆瓣电影</a>
# </div>
# <div class="nav-search">
# <form action="https://search.douban.com/movie/subject_search" method="get">
# <fieldset>
# <legend>搜索：</legend>
# <label for="inp-query">
# </label>
# <div class="inp"><input id="inp-query" maxlength="60" name="search_text" placeholder="搜索电影、电视剧、综艺、影人" size="22" value="邱淑贞"/></div>
# <div class="inp-btn"><input type="submit" value="搜索"/></div>
# <input name="cat" type="hidden" value="1002">
# </input></fieldset>
# </form>
# </div>
# </div>
# </div>
# <div class="nav-secondary">
# <div class="nav-items">
# <ul>
# <li><a href="https://movie.douban.com/cinema/nowplaying/">影讯&amp;购票</a>
# </li>
# <li><a href="https://movie.douban.com/explore">选电影</a>
# </li>
# <li><a href="https://movie.douban.com/tv/">电视剧</a>
# </li>
# <li><a href="https://movie.douban.com/chart">排行榜</a>
# </li>
# <li><a href="https://movie.douban.com/tag/">分类</a>
# </li>
# <li><a href="https://movie.douban.com/review/best/">影评</a>
# </li>
# <li><a href="https://movie.douban.com/annual/2019?source=navigation">2019年度榜单</a>
# </li>
# <li><a href="https://m.douban.com/standbyme/annual2019?source=navigation" target="_blank">2019书影音报告</a>
# </li>
# </ul>
# </div>
# <a class="movieannual" href="https://movie.douban.com/annual/2019?source=movie_navigation"></a>
# </div>
# </div>
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/19870c3/movie/bundle.js"></script>
# <div id="wrapper">
# <div class="root" id="root">
# <div class="search-title">正在搜索...</div>
# </div>
# <div id="browser-support"></div>
# <div id="footer">
# <span class="fleft gray-link" id="icp">
#     © 2005－2020 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
# <span class="fright">
# <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=main" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
# </div>
# </div>
# <script charset="utf-8" src="https://img3.doubanio.com/f/shire/5ecaf46d6954d5a30bc7d99be86ae34031646e00/js/douban.js"></script>
# <script type="text/javascript">
#     window.__DATA__ = "...";
#       window.__USER__ = { }
#
#   </script>
# <script charset="utf-8" src="//img3.doubanio.com/dae/staticng/s/search/79ec6251e9fc8a33e73c9b4e026c6dd3f2a3d973/dist/vendor.js"></script>
# <script charset="utf-8" src="//img3.doubanio.com/dae/staticng/s/search/79ec6251e9fc8a33e73c9b4e026c6dd3f2a3d973/dist/bundle.js"></script>
# <link href="https://img9.doubanio.com/dae/cdnlib/libs/browser-support/1.0.0/browser-support.css " rel="stylesheet"/>
# <script charset="utf-8" src="https://img9.doubanio.com/dae/cdnlib/libs/browser-support/1.0.0/browser-support.js?v=1"></script>
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'RHW2bWTEjaY',
#             criteria = '8:邱淑贞|3:/movie/subject_search?search_text=%E9%82%B1%E6%B7%91%E8%B4%9E&amp;cat=1002&amp;Accept=text%2Fhtml%2Capplication%2Fxhtml%2Bxml%2Capplication%2Fxml%3Bq%3D0.9%2Cimage%2Favif%2Cimage%2Fwebp%2Cimage%2Fapng%2C%2A%2F%2A%3Bq%3D0.8%2Capplication%2Fsigned-exchange%3Bv%3Db3%3Bq%3D0.9&amp;Accept-Encoding=gzip%2C+deflate%2C+br&amp;Accept-Language=zh-CN%2Czh%3Bq%3D0.9%2Cen-US%3Bq%3D0.8%2Cen%3Bq%3D0.7&amp;Connection=keep-alive&amp;Cookie=ll%3D%22108296%22%3B+bid%3D5yk8By15_aw%3B+douban-fav-remind%3D1%3B+_vwo_uuid_v2%3DD1A2FF7C0D139157D1720891778396435%7C38e03d0bdee142cddb55ddcaf01dca7f%3B+__utmc%3D30149280%3B+ap_v%3D0%2C6.0%3B+__utma%3D30149280.1750674411.1606877571.1606877571.1606919809.2%3B+__utmz%3D30149280.1606919809.2.2.utmcsr%3Dbaidu%7Cutmccn%3D%28organic%29%7Cutmcmd%3Dorganic%3B+__gads%3DID%3D82ae38b9c0f6cd34-226c1582f9c40097%3AT%3D1606919812%3ART%3D1606919812%3AS%3DALNI_Mb1h3Feev45xrBZuSjclfsoKr3Fww%3B+__utmt%3D1%3B+__utmb%3D30149280.1.10.1606919809&amp;Host=help.douban.com&amp;Referer=https%3A%2F%2Fsearch.douban.com%2Fmovie%2Fsubject_search%3Fsearch_text%3D%25E9%2582%25B1%25E6%25B7%2591%25E8%25B4%259E%26cat%3D1002&amp;Sec-Fetch-Dest=iframe&amp;Sec-Fetch-Mode=navigate&amp;Sec-Fetch-Site=same-site&amp;Upgrade-Insecure-Requests=1&amp;User-Agent=Mozilla%2F5.0+%28Macintosh%3B+Intel+Mac+OS+X+10_16_0%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F85.0.4183.121+Safari%2F537.36',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_subject_search_top_right', 'dale_movie_subject_search_bottom'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/czF5ODV4Ni9mL2FkanMvMjBiYWY2MDg2ZWQ0MDE1YTNmMDJhNDYxMzhmNmM0MjQxYjExYWYwMC9hZC5yZWxlYXNlLmpz');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
# <script type="text/javascript">
# $(function () {
# var n = new Date(), d = new Date(2011, 8, 3);
# if(n < d) {
#     var matchTxt = '?search_text=', matchTxtEnd = '&cat=1002', url = window.location.href,
#     start = url.indexOf(matchTxt) ,  end = url.indexOf(matchTxtEnd),
#     m = url.substring(start + matchTxt.length, end);
#     if (m == encodeURIComponent('变形金刚')) {
#         $('#google_ads_slot_subject_search_top_right').remove();
#         $('.aside').prepend('<div class="mb20"><a href="https://www.douban.com/link2?type=redir&vendor=tf3_mvsearch&url=http://a947.oadz.com/link/C/947/12341/5b34v5fh35XhrKFPSvSu.qqNk2Q_/p007/72/http://tf3.thinkworld.com.cn" target="_blank"><img src="https://img1.doubanio.com/img/files/file-131117411411517.jpg" width="310px" height="800px" /></a></div>');
# 	} else if (m == encodeURIComponent('意大利')) {
#         $('#google_ads_slot_subject_search_top_right').remove();
#         $('.aside').prepend('<div class="mb20"><iframe width="310" height="188" scrolling="no" frameborder="0" src="https://www.douban.com/biz/ad_page?slot=temp_1"></iframe></div>');
# 	}
# }});
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5WP579" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5WP579');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
# <script type="text/javascript">
# var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-7019765-1']);
# _gaq.push(['_setCampNameKey', 'dcn']);
# _gaq.push(['_setCampSourceKey', 'dcs']);
# _gaq.push(['_setCampMediumKey', 'dcm']);
# _gaq.push(['_setCampTermKey', 'dct']);
# _gaq.push(['_setCampContentKey', 'dcc']);
# _gaq.push(['_addOrganic', 'baidu', 'word']);
# _gaq.push(['_addOrganic', 'soso', 'w']);
# _gaq.push(['_addOrganic', '3721', 'name']);
# _gaq.push(['_addOrganic', 'youdao', 'q']);
# _gaq.push(['_addOrganic', 'so.360.cn', 'q']);
# _gaq.push(['_addOrganic', 'vnet', 'kw']);
# _gaq.push(['_addOrganic', 'sogou', 'query']);
# _gaq.push(['_addIgnoredOrganic', '豆瓣']);
# _gaq.push(['_addIgnoredOrganic', 'douban']);
# _gaq.push(['_addIgnoredOrganic', '豆瓣网']);
# _gaq.push(['_addIgnoredOrganic', 'www.douban.com']);
# _gaq.push(['_setDomainName', '.douban.com']);
#
#
#     _gaq.push(['_setCustomVar', 1, 'responsive_view_mode', 'desktop', 3]);
#
# _gaq.push(['_trackPageview']);
# _gaq.push(['_trackPageLoadTime']);
#
# window._ga_init = function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# };
# if (window.addEventListener) {
#     window.addEventListener('load', _ga_init, false);
# } else {
#     window.attachEvent('onload', _ga_init);
# }
# </script>
# <script type="text/javascript">
#     (function() {
#       DetectBrowser({
#         domId: 'browser-support',
#         callback: function(ok) {
#           if (!ok) {
#             var $root = document.getElementById('root')
#             $root && $root.parentElement.removeChild($root)
#           }
#         }
#       })
#     }())
#   </script>
# </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3334a22a7098> in <module>
#      58 BaseUrl = 'https://search.douban.com/movie/subject_search?search_text=%E9%82%B1%E6%B7%91%E8%B4%9E&cat=1002'
#      59 html = getHTMLText(BaseUrl,headers)
# ---> 60 datalist = getData(html)
#      61 print(datalist)
#      62 # saveData(datalist,str('movie_qsz.xls'))
#
# <ipython-input-20-3334a22a7098> in getData(html)
#      23     datalist = [] # 用于存放提取到全部Chat信息
#      24     # 便利每一条chat
# ---> 25     for item in list.find_all('div', attrs={'class':'sc-bZQynM'}):
#      26         data = []
#      27         # 提取标题
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
div.class = 'shIOW'

# %%
sc-bZQynM cVobZR sc-bxivhb eJWSlY

# %%
a = 'abcdefghijklmnopqrstuvwxyz'

print(f'{a[5]}{a[20]}{a[2]}{a[10]}{a[8]}{a[13]}{a[6]} {a[19]}{a[7]}{a[4]} {a[18]}{a[1]}')
