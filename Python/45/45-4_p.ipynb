# %%
from sklearn import preprocessing
import numpy as np

# %%
x = np.array([[0., -3., 1.], [3., 1., 2.], [0., 1., -1.]])

# %%
min_max_scaler = preprocessing.MinMaxScaler()
minmax_x = min_max_scaler.fit_transform(x)
print('**'*20, '\n', minmax_x)
# Out:
# ****************************************
#  [[0.         0.         0.66666667]
#  [1.         1.         1.        ]
#  [0.         1.         0.        ]]

# %%
scaled_x = preprocessing.scale(x)
print('**'*20, '\n', scaled_x)
# Out:
# ****************************************
#  [[-0.70710678 -1.41421356  0.26726124]
#  [ 1.41421356  0.70710678  1.06904497]
#  [-0.70710678  0.70710678 -1.33630621]]

# %%
j = np.ceil(np.log10(np.max(abs(x))))
scaled_x = x/(10**j)
print('**'*20, '\n', scaled_x)
# Out:
# ****************************************
#  [[ 0.  -0.3  0.1]
#  [ 0.3  0.1  0.2]
#  [ 0.   0.1 -0.1]]

# %%
x = np.array([[5000.], [16000.], [58000.]])
min_max_scaler = preprocessing.MinMaxScaler()
minmax_x = min_max_scaler.fit_transform(x)
print(minmax_x)
# Out:
# [[0.        ]
#  [0.20754717]
#  [1.        ]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
N = 1000
x = np.random.randn(N)
y = np.random.randn(N)

# %%
# %matplotlib inline
plt.scatter(x, y, marker='x')

# %%
df = pd.DataFrame({'x':x, 'y':y})
sns.jointplot(x='x', y='y', data=df, kind='scatter')

# %%
x = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y = [5, 3, 6, 20, 17, 20, 15, 6, 29, 38]
plt.plot(x, y)

# %%
df = pd.DataFrame({'x':x, 'y':y})
sns.lineplot(x='x', y='y', data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
a = np.random.randn(100)
s = pd.Series(a)
plt.hist(s)
# Out:
# (array([ 1.,  2.,  4.,  6., 13., 24., 22.,  9., 14.,  5.]),
#  array([-3.19876879, -2.64456547, -2.09036215, -1.53615882, -0.9819555 ,
#         -0.42775218,  0.12645114,  0.68065446,  1.23485778,  1.7890611 ,
#          2.34326443]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(s, kde=False)

# %%
sns.displot(s, kde=True)

# %%
x = ['Cat1', 'Cat2', 'Cat3', 'Cat4', 'Cat5']
y = [5,4,8,12,7]
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(x, y)
# Out:
# /Users/du/miniforge3/envs/tf/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
data = np.random.normal(size=(10, 4))
labels = ['A', 'B', 'C', 'D']
plt.boxplot(data, labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14dd85b50>,
#   <matplotlib.lines.Line2D at 0x14dd85ee0>,
#   <matplotlib.lines.Line2D at 0x14dda74c0>,
#   <matplotlib.lines.Line2D at 0x14dda7850>,
#   <matplotlib.lines.Line2D at 0x14ddb0df0>,
#   <matplotlib.lines.Line2D at 0x14ddbe1c0>,
#   <matplotlib.lines.Line2D at 0x14ddc7760>,
#   <matplotlib.lines.Line2D at 0x14ddc7af0>],
#  'caps': [<matplotlib.lines.Line2D at 0x14dd9c2b0>,
#   <matplotlib.lines.Line2D at 0x14dd9c640>,
#   <matplotlib.lines.Line2D at 0x14dda7be0>,
#   <matplotlib.lines.Line2D at 0x14dda7f70>,
#   <matplotlib.lines.Line2D at 0x14ddbe550>,
#   <matplotlib.lines.Line2D at 0x14ddbe8e0>,
#   <matplotlib.lines.Line2D at 0x14ddc7e80>,
#   <matplotlib.lines.Line2D at 0x14ddd2250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x14db7feb0>,
#   <matplotlib.lines.Line2D at 0x14dda7130>,
#   <matplotlib.lines.Line2D at 0x14ddb0a60>,
#   <matplotlib.lines.Line2D at 0x14ddc73d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14dd9c9d0>,
#   <matplotlib.lines.Line2D at 0x14ddb0340>,
#   <matplotlib.lines.Line2D at 0x14ddbec70>,
#   <matplotlib.lines.Line2D at 0x14ddd25e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14dd9cd60>,
#   <matplotlib.lines.Line2D at 0x14ddb06d0>,
#   <matplotlib.lines.Line2D at 0x14ddc7040>,
#   <matplotlib.lines.Line2D at 0x14ddd2970>],
#  'means': []}

# %%
df = pd.DataFrame(data, columns=labels)
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
nums = [25, 37, 33, 37, 6]
labels = ['H-School', 'Bachelor', 'Master', 'Ph.d', 'Others']
plt.pie(x=nums, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x14dfb7cd0>,
#   <matplotlib.patches.Wedge at 0x14dfd0250>,
#   <matplotlib.patches.Wedge at 0x14dfd0730>,
#   <matplotlib.patches.Wedge at 0x14dfd0c10>,
#   <matplotlib.patches.Wedge at 0x14dfc9130>],
#  [Text(0.9266076783810917, 0.5927885039077627, 'H-School'),
#   Text(-0.4382411947237755, 1.0089324334399594, 'Bachelor'),
#   Text(-0.9986952352308595, -0.4610941629723568, 'Master'),
#   Text(0.4837081783604924, -0.9879404831198964, 'Ph.d'),
#   Text(1.0897545367529526, -0.14978334228597634, 'Others')])

# %%
flights = sns.load_dataset('flights')
data = flights.pivot('year', 'month', 'passengers')
sns.heatmap(data)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
from matplotlib.font_manager import FontProperties
from matplotlib import font_manager
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
labels = np.array([u'推进','KDA','Life','团战','发育','输出'])
stats = [83, 61, 95, 67, 76, 88]

# %%
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
stats = np.concatenate((stats, [stats[0]]))
angles = np.concatenate((angles, [angles[0]]))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, stats, 'o-', linewidth=1)
ax.fill(angles, stats, alpha=0.25)
# ax.set_thetagrids(angles * 180/np.pi, labels)

# %%
tips = sns.load_dataset('tips')
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 91        22.49  3.50    Male     No   Fri  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 137       14.15  2.00  Female     No  Thur   Lunch     2
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)
