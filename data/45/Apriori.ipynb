# %%
# 超市购物
from efficient_apriori import apriori
import pandas as pd
data = [['牛奶','面包','尿布'],
           ['可乐','面包', '尿布', '啤酒'],
           ['牛奶','尿布', '啤酒', '鸡蛋'],
           ['面包', '牛奶', '尿布', '啤酒'],
           ['面包', '牛奶', '尿布', '可乐']]

# 挖掘频繁项集和频繁规则
itemsets, rules = apriori(data,min_support=0.5,min_confidence=1)
print(f'itemsets:\n{itemsets},\nrules:\n{rules}')
# Out:
# itemsets:
# {1: {('面包',): 4, ('尿布',): 5, ('牛奶',): 4, ('啤酒',): 3}, 2: {('尿布', '牛奶'): 4, ('尿布', '面包'): 4, ('牛奶', '面包'): 3, ('啤酒', '尿布'): 3}, 3: {('尿布', '牛奶', '面包'): 3}},
# rules:
# [{牛奶} -> {尿布}, {面包} -> {尿布}, {啤酒} -> {尿布}, {牛奶, 面包} -> {尿布}]

# %%
# 抓取某个导演的电影数据集
from efficient_apriori import apriori
from lxml import etree
import time
from selenium import webdriver
import csv

driver = webdriver.Chrome('/Applications/chromedriver')  # Optional argument, if not specified will search path.

# 设置想要下载的导演，数据集
director = '姜文'

# 写入CSV文件
file_name = 'data/'+director+'.csv'
base_url = 'https://movie.douban.com/subject_search?search_text='+director+'&cat=1002&start='
out = open(file_name, 'w', newline='', encoding='utf-8-sig')
csv_write = csv.writer(out, dialect='excel')
flags=[]

# 下载指定页面的数据
def download(request_url):
  driver.get(request_url)
  time.sleep(1)
  html = driver.find_element_by_xpath("//*").get_attribute("outerHTML")
  html = etree.HTML(html)
  # 设置电影名称，导演演员 的XPATH
  movie_items = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='title']/a[@class='title-text']")
  name_items = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='meta abstract_2']")
  # 获取返回的数据个数
  num = len(movie_items)
  if num > 15: #第一页会有16条数据
    # 默认第一个不是，所以需要去掉
    movie_items = movie_items[1:]
    name_items = name_items[1:]
  for (movie, name_item) in zip(movie_items, name_items):
    # 会存在数据为空的情况
    if name_item.text is None: 
      continue
    # 显示下演员名称
    print(f'movie:\n{movie.text}\nnames:\n{name_item.text}')
    names = name_item.text.split('/')
    # 判断导演是否为指定的director
    if names[0].strip() == director and movie.text not in flags:
      # 将第一个字段设置为电影名称
      names[0] = movie.text
      flags.append(movie.text)
      csv_write.writerow(names)
  print('OK') # 代表这页数据下载成功
  print(num)
  if num >= 14: #有可能一页会有14个电影
    # 继续下一页
    return True
  else:
    # 没有下一页
    return False

# 开始的ID为0，每页增加15
start = 0
while start<10000: #最多抽取1万部电影
  request_url = base_url + str(start)
  # 下载数据，并返回是否有下一页
  flag = download(request_url)
  if flag:
    start = start + 15
  else:
    break

# 关闭程序，结束
out.close()
print('finished')
# Out:
# movie:
# 让子弹飞‎ (2010)
# names:
# movie:
# 父母爱情‎ (2020)
# names:
# 姜文
# movie:
# 晓说2018‎ (2018)
# names:
# 高晓松 / 徐克 / 吴宇森 / 冯小刚 / 樊建川 / 黄健翔 / 姜文 / 高晓攀
# movie:
# 末代皇后‎ (1987)
# names:
# 潘虹 / 傅艺伟 / 姜文 / 正华 / 刘威
# movie:
# 图兰朵：魔咒缘起‎ (2021)
# names:
# 郑晓龙 / 关晓彤 / 迪伦·斯普罗斯 / 姜文 / 胡军 / 苏菲·玛索 / 林思意 / 王嘉 / 文森特·佩雷斯
# movie:
# 长河东流‎ (2008)
# names:
# 彭军 / 谢震伟 / 李明 / 姜文 / 刘晓庆 / 高兰村 / 安亚平 / 王亚楠 / 伊能静
# movie:
# 圆桌讲究派‎ (2018)
# names:
# 窦文涛 / 姜文 / 马未都 / 孟广美
# movie:
# 金婚·风雨情‎ (2009)
# names:
# 郑晓龙 / 胡军 / 周韵 / 李立群 / 王思懿 / 涂凌 / 杜宁林 / 李心敏 / 秦海璐
# movie:
# 乘着光影旅行——李屏宾的摄影人生‎ (2009)
# names:
# 关本良 / 姜秀琼 / 李屏宾 / 杜笃之 / 张艾嘉 / 王家卫 / 陈昌纶 / 侯孝贤 / 舒淇 / 吉尔·布尔多
# movie:
# 大清风云‎ (2005)
# names:
# 陈家林 / 张丰毅 / 许晴 / 姜文 / 孙淳 / 李光洁 / 王绘春 / 韩晓 / 唐以诺
# movie:
# 春桃‎ (1988)
# names:
# 凌子风 / 刘晓庆 / 姜文 / 曹前明 / 冯汉元 / 王心丽 / 姚建国 / 孙玉珍
# movie:
# 北京记忆‎ (2012)
# names:
# 袁子勇 / 吴群 / 孟京辉 / 邹静之 / 邓小平 / 柳传志 / 陈景润 / 叶剑英 / 曹景行 / 小泽征尔
# OK
# 15
# movie:
# 狭路英豪‎ (1993)
# names:
# 周晓文 / 姜文 / 万梓良 / 于莉
# movie:
# 看球记‎ (2011)
# names:
# 姜文 / 刘利年
# movie:
# 花轿泪 Le Palanquin des Larmes‎ (1987)
# names:
# Jacques Dorfmann / 姜文 / Henry O / Beulah Quo
# movie:
# 第十届中国电影导演协会年度奖‎ (2019)
# names:
# 贾樟柯 / 姜文 / 张艺谋 / 文牧野 / 毕赣 / 黄渤 / 徐峥 / 章宇
# movie:
# 中国原创音乐20年‎ (2011)
# names:
# 张艺馨 / 崔健 / 王迪 / 丁武 / 老五 / 张楚 / 何勇 / 姜文 / 安迪
# movie:
# 电影系列：新中国影视作品中的性 Moving Pictures: Sex in the New Chinese Cinema‎ (1993)
# names:
# 陈凯歌 / 姜文 / 吕丽萍
# movie:
# 故事：制作《星球大战外传：侠盗一号》 The Stories: The Making of 'Rogue One: A Star Wars Story'‎ (2017)
# names:
# Glen Milner / Ian Bucknole / 凯瑟琳·肯尼迪 / 约翰·诺尔 / Kiri Hart / 江道格 / John Swartz / 加里斯·爱德华斯 / 艾莉森·希尔默 / 菲丽希缇·琼斯
# movie:
# 我和我的小伙伴们‎ (2020)
# names:
# 柳杰 / 刘璇 / 巴彦 / 阿里玛肯 / 海力力
# movie:
# 夺宝同盟之凤凰宝藏‎ (2018)
# names:
# 杨晟 / 释彦能 / 吉丽 / 刘峰超 / 博尔吉特 / 赵品霖 / 郭佳伊 / 楚晓龙 / 金钊
# movie:
# 梦寻巴厘岛‎ (2020)
# names:
# 刘俊辉 / 王智 / 姜至奂 / 潘霜霜 / 傅传杰 / 陈国坤
# movie:
# 兄弟营‎ (2018)
# names:
# 海顿 / 翁虹 / 赵恒煊 / 杨峰
# OK
# 15
# movie:
# 女魔头之恋 รักของนางร้าย‎ (2020)
# names:
# Koo Ekkasit Trakulkasemsuk / 苏卡达·顾珑希 / 吴梦凡 / 塔纳本·万罗西力侬
# movie:
# 第3届中国电影导演协会年度奖‎ (2012)
# names:
# 姜文 / 张猛 / 滕华涛 / 冯小刚 / 顾长卫 / 文章 / 葛优 / 周润发
# movie:
# 加油！小茉‎ (2018)
# names:
# 麦贯之 / 海陆 / 高仁 / 郭子渝
# movie:
# 剑安天下之灵狐剑‎ (2020)
# names:
# 孔钦宁 / 李延桢 / 胡文珊 / 严洪智 / 任春茹 / 杨景江
# movie:
# 素女真经 素女真經‎ (1980)
# names:
# 王强 / 王美玲 / 刘文妹 / 林晋升 / 徐贵生 / 林得顺 / 李云玉 / 古木泉 / 林碧霞
# movie:
# 造爱人间‎ (1998)
# names:
# 王精 / 郭小霜 / 林泽明 / 杨梵 / 林科 / 郭义凯 / 连惠玟 / 吴彰鹏 / 郑国安
# movie:
# 爱上蒲女团：终章‎ (2018)
# names:
# 吉米 / 张已桂 / 文卓 / 陶大宇 / 梁证嘉 / 陈霜
# movie:
# 美熟女假面的咒缚 美熟女フォンテーヌ ~絶倫仮面の呪縛~‎ (2017)
# names:
# 三島奈津子
# movie:
# 捉奸记‎ (2016)
# names:
# 吕乐 / 高亚麟 / 尤浩然
# movie:
# 百家讲坛—唐宋八大家之王安石‎ (2011)
# names:
# 康震
# movie:
# 十恶不赦‎ (2016)
# names:
# 杨帅 / 海萍 / 大崎明 / 祁楚尭
# movie:
# ミツバチと甘い花蜜‎ (2017)
# names:
# 宮瀬博教 / 吉井美希 / 片岡なぎさ / 浅井陽登 / 藤原則子
# movie:
# 麻辣主播‎ (2017)
# names:
# 尚大庆 / 田昊 / 张嘉俊 / 火旺 / 朱璐 / 杨祖青 / 张嘉
# movie:
# 笔仙之生死劫2‎ (2017)
# names:
# 陶昊宇 / 郜晓雨 / 垚鑫玉 / 葛晨晨
# OK
# 15
# movie:
# 索命Call In‎ (2004)
# names:
# 黄泽清 / 狄威 / 何家驹 / 黄健群 / 莫少琳 / 彭彦斌 / 刘秋梅 / 于伟文 / 雷鹏
# movie:
# 晚吹﹣真PK‎ (2016)
# names:
# 黄慧君 / 火火 / 李健宏 / 林雪 / 郭伟亮 / 郑中基 / 钱国伟 / 王灏儿 / 曾国祥
# 费多·德米提亚夫  / 彼得·费奥多罗夫 / 叶夫根尼·斯迪查金
# movie:
# 咖啡女郎‎ (1984)
# names:
# 萧尧 / 袁嘉佩 / 高振鹏 / 郑一德
# movie:
# 盘古开天地‎ (1979)
# names:
# 羅山 / 岳華 / 陳星 / 林伊娃
# movie:
# 美丽的琪琪格‎ (2017)
# names:
# 周军 / 端木崇慧 / 郭志桐 / 梓霖 / 莫涂弘哲 / 李勤勤 / 高峰 / 佟仲琪 / 图和
# movie:
# 実写本番ONANIE‎ (1991)
# names:
# 鈴木敬晴 / 五岛惠美 / 清水大敬 / 南野千夏 / 伊藤清美 / 牧村耕次 / 小林节彦 / 早川诚 / 一辉郁雄
# movie:
# 假正经‎ (1959)
# names:
# 陳翼青 / 陈列 / 丁兰 / 黃英 / 王清河 / 王金波 / 庄甦
# movie:
# バブルと寝た愛人たち‎ (2016)
# names:
# 桐島秋子 / 天野小雪 / 吉井美希 / バクシーシ山下
# movie:
# 一夜狂奔‎ (2017)
# names:
# 陈俊任 / 俞昊翔 / 方妍心 / 张皓羽 / 沈昶宏
# OK
# 13
# finished

# %%
# 加载数据

from efficient_apriori import apriori
import csv
director = '姜文'
file_name = 'data/'+director+'.csv'
lists = csv.reader(open(file_name, 'r', encoding='utf-8-sig'))
# 数据加载
data = []
for names in lists:
    name_new = []
    for name in names:
        # 去掉演员数据中的空格
        name_new.append(name.strip())
    data.append(name_new[1:])
print(data)
# 挖掘频繁项集和关联规则
itemsets, rules = apriori(data, min_support=0.1, min_confidence=1)
print(f'itemsets:\n{itemsets},\nrules:\n{rules}')
# Out:
# [['葛优', '周润发', '刘嘉玲', '陈坤', '张默', '姜武', '周韵'], ['香川照之', '袁丁', '姜宏波', '丛志军', '李从喜', '泽田谦也', '李海滨'], ['夏雨', '宁静', '陶虹', '耿乐', '斯琴高娃', '冯小刚', '刘小宁'], ['彭于晏', '廖凡', '周韵', '许晴', '泽田谦也', '安地', '史航'], ['房祖名', '周韵', '黄秋生', '陈冲', '孔维', '崔健', '李加民'], ['葛优', '周韵', '舒淇', '文章', '王志文', '洪晃', '刘利年'], ['周韵'], [], ['刘利年'], ['姚晨', '洪晃'], ['夏雨', '萧芳芳', '张国荣', '顾长卫', '王童', '尔冬升', '罗志良'], ['韩昀珊'], ['张猛', '滕华涛', '冯小刚', '顾长卫', '文章', '葛优', '周润发']]
# itemsets:
# {1: {('周韵',): 5, ('周润发',): 2, ('葛优',): 3, ('泽田谦也',): 2, ('夏雨',): 2, ('冯小刚',): 2, ('洪晃',): 2, ('文章',): 2, ('刘利年',): 2, ('顾长卫',): 2}, 2: {('周润发', '葛优'): 2, ('周韵', '葛优'): 2, ('文章', '葛优'): 2}},
# rules:
# [{周润发} -> {葛优}, {文章} -> {葛优}]

# %%
# 实验strip()方法
str_items = "钟澍佳 / 杜淳 / 马苏 / 李若嘉 / 武强 / 王德顺 / 李亚天 / 谢园 / 张殿伦"
strs = str_items.split('/')
strs[0].strip()
# Out:
# '钟澍佳'

# %%
# 作业 - 抓取数据

# 抓取某个导演的电影数据集
from efficient_apriori import apriori
from lxml import etree
import time
from selenium import webdriver
import csv

driver = webdriver.Chrome('/Applications/chromedriver')  # Optional argument, if not specified will search path.

# 设置想要下载的导演，数据集
director = '张艺谋'

# 写入CSV文件
file_name = 'data/'+director+'.csv'
base_url = 'https://movie.douban.com/subject_search?search_text='+director+'&cat=1002&start='
out = open(file_name, 'w', newline='', encoding='utf-8-sig')
csv_write = csv.writer(out, dialect='excel')
flags=[]

# 下载指定页面的数据
def download(request_url):
  driver.get(request_url)
  time.sleep(1)
  html = driver.find_element_by_xpath("//*").get_attribute("outerHTML")
  html = etree.HTML(html)
  # 设置电影名称，导演演员 的XPATH
  movie_items = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='title']/a[@class='title-text']")
  name_items = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='meta abstract_2']")
  # 获取返回的数据个数
  num = len(movie_items)
  if num > 15: #第一页会有16条数据
    # 默认第一个不是，所以需要去掉
    movie_items = movie_items[1:]
    name_items = name_items[1:]
  for (movie, name_item) in zip(movie_items, name_items):
    # 会存在数据为空的情况
    if name_item.text is None: 
      continue
    # 显示下演员名称
    print(f'movie:\n{movie.text}\nnames:\n{name_item.text}')
    names = name_item.text.split('/')
    # 判断导演是否为指定的director
    if names[0].strip() == director and movie.text not in flags:
      # 将第一个字段设置为电影名称
      names[0] = movie.text
      flags.append(movie.text)
      csv_write.writerow(names)
  print('OK') # 代表这页数据下载成功
  print(num)
  if num >= 14: #有可能一页会有14个电影
    # 继续下一页
    return True
  else:
    # 没有下一页
    return False

# 开始的ID为0，每页增加15
start = 0
while start<10000: #最多抽取1万部电影
  request_url = base_url + str(start)
  # 下载数据，并返回是否有下一页
  flag = download(request_url)
  if flag:
    start = start + 15
  else:
    break

# 关闭程序，结束
out.close()
print('finished')
# Out:
# movie:
# 张艺谋：中国故事 "Arena" Zhang Yimou‎ (1993)
# names:
# 克里斯托弗·布鲁斯 / 张艺谋 / 张秉钧 / 张孝友 / 巩俐 / 张艾嘉 / 莫言
# movie:
# 一秒钟‎ (2020)
# names:
# 张艺谋 / 张译 / 刘浩存 / 范伟 / 余皑磊 / 张邵勃  / 李延 / 于洋 / 刘云龙
# movie:
# 活着‎ (1994)
# names:
# 张艺谋 / 葛优 / 巩俐 / 姜武 / 牛犇 / 郭涛 / 张璐 / 倪大红 / 肖聪
# movie:
# 金陵十三钗‎ (2011)
# names:
# 张艺谋 / 克里斯蒂安·贝尔 / 倪妮 / 张歆怡 / 黄天元 / 韩熙庭 / 张逗逗 / 佟大为 / 曹可凡
# movie:
# 影‎ (2018)
# names:
# 张艺谋 / 邓超 / 孙俪 / 郑恺 / 王千源 / 王景春 / 胡军 / 关晓彤 / 吴磊
# movie:
# Días de cine‎ (1991)
# names:
# 塞缪尔·马丁·马特奥斯 / Antonio Gasset
# movie:
# Hayom BaLayla‎ (2015)
# names:
# Evyatar Halimi / 亚伯拉罕·阿维夫·亚录许 / 内莉· 塔加尔 / 古里·阿尔菲 / Dar Zuzovsky / 加尔·托伦 / 锡安·巴鲁克 / 阿尼娅·布克斯坦 / 张艺谋
# movie:
# 第75届威尼斯国际电影节颁奖典礼 The 75th Mostra Internazionale d'Arte Cinematografica di Ve‎ (2018)
# names:
# 阿方索·卡隆 / 欧格斯·兰斯莫斯 / 奥利维娅·科尔曼 / 万玛才旦 / 威廉·达福 / 大卫·柯南伯格 / 伊桑·科恩 / 乔·科恩
# movie:
# “满城尽带黄金甲”幕后揭秘 Secrets Within: Inside Look at 'Curse of the Golden Flower'‎ (2007)
# names:
# Stanley J. Orzel / 周杰伦 / 周润发 / 巩俐 / Beau Weaver / 张艺谋
# movie:
# 血汗杜兰朵 The Turandot Project‎ (2000)
# names:
# 艾伦·米勒
# OK
# 11
# finished

# %%
# 作业-加载并挖掘数据

from efficient_apriori import apriori
import csv
director = '张艺谋'
file_name = 'data/'+director+'.csv'
lists = csv.reader(open(file_name, 'r', encoding='utf-8-sig'))
# 数据加载
data = []
for names in lists:
    name_new = []
    for name in names:
        # 去掉演员数据中的空格
        name_new.append(name.strip())
    data.append(name_new[1:])
print(data)
# 挖掘频繁项集和关联规则
itemsets, rules = apriori(data, min_support=0.05, min_confidence=1)
print(f'itemsets:\n{itemsets},\nrules:\n{rules}')
# Out:
# [['张译', '刘浩存', '范伟', '余皑磊', '张邵勃', '李延', '于洋', '刘云龙'], ['葛优', '巩俐', '姜武', '牛犇', '郭涛', '张璐', '倪大红', '肖聪'], ['克里斯蒂安·贝尔', '倪妮', '张歆怡', '黄天元', '韩熙庭', '张逗逗', '佟大为', '曹可凡'], ['邓超', '孙俪', '郑恺', '王千源', '王景春', '胡军', '关晓彤', '吴磊'], ['李连杰', '梁朝伟', '张曼玉', '章子怡', '陈道明', '甄子丹'], ['巩俐', '姜文', '滕汝骏', '钱明', '陈志刚', '计春华'], ['周润发', '巩俐', '周杰伦', '刘烨', '陈瑾', '倪大红', '李曼', '秦俊杰'], ['马特·达蒙', '景甜', '佩德罗·帕斯卡', '刘德华', '威廉·达福', '张涵予', '鹿晗', '彭于晏'], ['姜文', '李保田', '瞿颖', '刘信义', '葛优', '李雪健', '尤勇智'], ['陈道明', '巩俐', '张慧雯', '郭涛', '刘佩琦', '祖峰', '闫妮', '辛柏青'], ['金城武', '刘德华', '章子怡', '宋丹丹', '刘腾远', '赵鸿飞', '郭军', '张恕'], ['巩俐', '马精武', '何赛飞', '曹翠芬', '周琦', '孔琳', '金淑媛', '丁惟敏'], ['周冬雨', '窦骁', '奚美娟', '李雪健', '姜瑞佳', '于新博', '萨日娜', '成泰燊'], ['杨凤良', '巩俐', '李保田', '李纬', '丛志军', '金甲', '牛星丽'], ['雷佳音', '张国立', '于和伟', '周冬雨', '孙艺洲', '李乃文', '许亚军', '田雨'], ['章子怡', '郑昊', '孙红雷', '李滨', '嵇波', '宋运成'], ['魏敏芝', '张慧科', '田正达', '高恩满', '孙志梅', '冯玉英', '李凡凡', '张艺长'], ['巩俐', '刘佩琦', '雷恪生', '戈治均', '杨柳春', '朱万清', '崔络纹', '杨惠琴'], ['张译', '于和伟', '秦海璐', '朱亚文', '刘浩存', '倪大红', '李乃文', '余皑磊'], [], ['小沈阳', '闫妮', '孙红雷', '倪大红', '程野', '毛毛', '赵本山'], ['巩俐', '李保田', '李雪健', '孙淳', '傅彪', '陈述', '刘江', '蒋宝英'], ['高仓健', '蒋雯', '邱林', '寺岛忍', '中井贵一', '中本贤'], ['张继刚', '陈维亚', '蒂姆·达格特', 'Elfi Schlegel', 'Al Trautwig'], ['董洁', '赵本山', '傅彪', '李雪健', '董立范', '牛犇', '张洪杰', '孙红雷'], ['张译', '章宇', '刘浩存'], ['杨凤良', '刘小宁', '葛优', '巩俐', '王学圻', '于荣光'], ['香川照之'], [], ['申雪', '赵宏博', '林更新', '张静初', '曹格', '左小青', '孙艺洲', '李菲儿'], ['廖昌永', '赵聪'], ['谢飞', '黄建新', '王晓棠', '李雪健', '唐国强'], ['桑吉加'], ['吕聿来', '李曼'], [], ['Peng Wang'], []]
# itemsets:
# {1: {('张译',): 3, ('刘浩存',): 3, ('余皑磊',): 2, ('葛优',): 3, ('郭涛',): 2, ('牛犇',): 2, ('倪大红',): 4, ('巩俐',): 9, ('章子怡',): 3, ('陈道明',): 2, ('姜文',): 2, ('李曼',): 2, ('刘德华',): 2, ('李雪健',): 5, ('李保田',): 3, ('闫妮',): 2, ('刘佩琦',): 2, ('周冬雨',): 2, ('杨凤良',): 2, ('孙艺洲',): 2, ('于和伟',): 2, ('李乃文',): 2, ('孙红雷',): 3, ('赵本山',): 2, ('傅彪',): 2}, 2: {('余皑磊', '刘浩存'): 2, ('余皑磊', '张译'): 2, ('刘浩存', '张译'): 3, ('倪大红', '巩俐'): 2, ('巩俐', '葛优'): 2, ('巩俐', '郭涛'): 2, ('李保田', '李雪健'): 2, ('刘佩琦', '巩俐'): 2, ('巩俐', '李保田'): 2, ('巩俐', '杨凤良'): 2, ('于和伟', '李乃文'): 2, ('孙红雷', '赵本山'): 2, ('傅彪', '李雪健'): 2}, 3: {('余皑磊', '刘浩存', '张译'): 2}},
# rules:
# [{余皑磊} -> {刘浩存}, {余皑磊} -> {张译}, {张译} -> {刘浩存}, {刘浩存} -> {张译}, {郭涛} -> {巩俐}, {刘佩琦} -> {巩俐}, {杨凤良} -> {巩俐}, {李乃文} -> {于和伟}, {于和伟} -> {李乃文}, {赵本山} -> {孙红雷}, {傅彪} -> {李雪健}, {余皑磊, 张译} -> {刘浩存}, {余皑磊, 刘浩存} -> {张译}, {余皑磊} -> {刘浩存, 张译}]
