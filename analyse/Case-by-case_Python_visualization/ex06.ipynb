# %%
# 关系统计图

# %%
# %matplotlib inline
import seaborn as sns

sns.set(style='ticks')
tips = sns.load_dataset('tips')
tips.sample(3)
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 2        21.01  3.50  Male     No  Sun  Dinner     3
# 19       20.65  3.35  Male     No  Sat  Dinner     3
# 95       40.17  4.73  Male    Yes  Fri  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
## relplot 完整参数列表
# seaborn.relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tips)

# %%
g = sns.relplot(x='total_bill', y='tip', hue='time', size='size', palette=['b','r'], sizes=(10, 100), col='time', data=tips)

# %%
## sns.scatterplot

# %%
ax = sns.scatterplot(x='total_bill', y='tip', hue='day', style='time', data=tips)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='day', size='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', hue='day', size='smoker', sizes=(50, 150), data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fmri=sns.load_dataset('fmri')
fmri.sample(3)
# Out:
#     subject  timepoint event   region    signal
# 984     s10          2   cue  frontal -0.019877
# 641      s9          4   cue  frontal  0.054909
# 496      s8         16  stim  frontal -0.064510

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x='timepoint', y='signal', data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
## sns.lineplot 完整参数列表
# seaborn.lineplot(x=None, y=None, hue=None, size=None, style=None, data=None, palette=None, hue_order=None, hue_norm=None , sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, units=None, estimator='mean', ci=95, n_boot=1000, sort=True, err_style='band', err_kws=None, legend='brief', ax=None, **kwargs)

# %%
sns.lineplot?
# Out:
# Signature:
# sns.lineplot(
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     size=None,
#     style=None,
#     data=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     sizes=None,
#     size_order=None,
#     size_norm=None,
#     dashes=True,
#     markers=None,
#     style_order=None,
#     units=None,
#     estimator='mean',
#     ci=95,
#     n_boot=1000,
#     seed=None,
#     sort=True,
#     err_style='band',
#     err_kws=None,
#     legend='auto',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Draw a line plot with possibility of several semantic groupings.
#
# The relationship between ``x`` and ``y`` can be shown for different subsets
# of the data using the ``hue``, ``size``, and ``style`` parameters. These
# parameters control what visual semantics are used to identify the different
# subsets. It is possible to show up to three dimensions independently by
# using all three semantic types, but this style of plot can be hard to
# ...

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri, hue='event', style='event', markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri, hue='event', style='event', markers=True, dashes=False,err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
import numpy as np
x = np.linspace(0, 100, 100)
y = np.sin(x) + np.random.random(100)
sns.lineplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
# 回归统计图

# %%
tips.sample(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
# sns.lmplot
sns.lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)

# sns.regplot
sns.regplot(x, y, data=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, marker='o', scatter_kws=None, line_kws=None, ax=None)

# %%
sns.regplot(x='total_bill', y='tip', data=tips, color='g', marker='+')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x='size', y='total_bill', data=tips, x_jitter=.1)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.regplot(x='size', y='total_bill', data=tips, x_estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# [link](marginnote3app://note/E3EE697A-CBA3-4666-97F8-6379958C4CC4)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips, markers=['o', 'x'])
