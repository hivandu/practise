# %% [markdown]
# # Seaborn

# %%
# %matplotlib inline

import tqdm

# 引入 seaborn 库
import seaborn as sns
# 可视化结果采用 Seaborn 默认的⻛格
sns.set()
# 获取数据集
tips = sns.load_dataset('tips')
# 对数据集进行可视化
sns.relplot(x='total_bill', y='tip', col='time', hue='smoker',  style='smoker', size='size', data=tips)

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 50        12.54  2.50    Male     No   Sun  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
## Seaborn 绘制柱状图
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x='class', y='survived', hue='sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.swarmplot(x='species', y='petal_length', data=iris)
# Out:
# /Users/du/miniforge3/envs/tf/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
## 分类数据的统计图

# sns.catplot(x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean>, ci=95, n_boot=1000, units=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)

# %% [markdown]
# ## 分类特征的散点图

# %%
# load data
import seaborn as sns
sns.set(style='whitegrid')

exercise = sns.load_dataset('exercise')
exercise.sample(5)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 71          71  24  low fat    120  30 min  running
# 80          80  27   no fat    140  30 min  running
# 19          19   7   no fat     88  15 min     rest
# 0            0   1  low fat     85   1 min     rest
# 2            2   1  low fat     88  30 min     rest

# %%
# 使用数据集制图
# %matplotlib inline
sns.catplot(x='time', y='pulse', hue='kind', data=exercise)

# %%
sns.stripplot(x='time', y='pulse', hue='kind', data=exercise)
# Out:
# <AxesSubplot:xlabel='time', ylabel='pulse'>

# %%
sns.catplot(x='time', y='pulse', hue='kind', col='diet', data=exercise, kind='strip')

# %%
## striplot 完整参数
# seaborn.stripplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
ax = sns.stripplot(x='time', y='pulse', data=exercise, jitter=0)

# %%
ax = sns.stripplot(x='time', y='pulse', data=exercise, jitter=0.05)

# %%
ax = sns.stripplot(x='time', y='pulse', data=exercise, hue='kind', dodge=True, palette='Set2')

# %%
## Swarmplot

tips = sns.load_dataset('tips')

sns.swarmplot(x='day', y='total_bill', data=tips)
# 等效的
# sns.catplot(x='day', y='total_bill', kind='swarm', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x=tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
## swarmplot 完整参数
# seaborn.swarmplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)

# %%
sns.swarmplot(x='day', y='total_bill', hue='smoker', data=tips, palette='Set2')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', hue='smoker', data=tips, palette='Set2', dodge=True)
# Out:
# /Users/du/miniforge3/envs/tf/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette='Set3')
# sns.catplot(x='day', y='total_bill', kind='box', hue='smoker', data=tips, palette='Set3')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# 把箱线图和前面的散点图结合起来,或许能有更多维度来观察数据
ax = sns.boxplot(x='day', y='total_bill', data=tips)
ax = sns.swarmplot(x='day', y='total_bill', data=tips, color='.25')

# %%
# boxplot 完整参数列表
# sns.boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)

# %%
# boxenplot 完整参数列表
# sns.boxenplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)

# %%
# boxenplot
ax = sns.boxenplot(x='day', y='total_bill', data=tips)
ax = sns.stripplot(x='day', y='total_bill', data=tips, size=4, jitter=True, color='gray')

# %%
# violinplot
sns.violinplot(x='day', y='total_bill', data=tips)
# 等效
# sns.catplot(x='day', y='total_bill', data=tips, kind='violin')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='smoker', palette='muted', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# violinplot完整参数
# sns.violinplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=None, gridsize=100, width=.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=.75, ax=None, **kwargs)

# %% [markdown]
# ## barplot

# %%
# load titanic data
titanic = sns.load_dataset('titanic')

# 绘制反映不同等级船舱中不同性别人士获救比率的簇状柱形图
g = sns.catplot(x='class', y='survived', data=titanic, hue='sex', height=6, kind='bar', palette='muted')
g.despine(left=True)
g.set_ylabels('Survival probability')

# %%
ax = sns.barplot(x='day', y='tip', data=tips, capsize=.2)

# %%
# barplot 完整参数列表
# sns.barplot(x=None, y=None, hue=None, data=None, order=N one, hue_order=None, estimator=<function mean>, ci=95, n_boo t=1000, units=None, orient=None, color=None, palette=None, s aturation=0.75, errcolor='.26', errwidth=None, capsize=None,  dodge=True, ax=None, **kwargs)

# %%
import numpy as np
sns.barplot(x='day', y='tip', data=tips, estimator=np.median)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pointplot(x='time', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.pointplot(x='time', y ='total_bill', hue='smoker', data=tips, markers=['o', 'x'], linestyles=['-','--'])
# Out:
# /Users/du/miniforge3/envs/tf/lib/python3.9/site-packages/seaborn/categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.8666666666666667, 0.5176470588235295, 0.3215686274509804)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
# 完整参数列表
# sns.pointplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean>, ci=95, n_boot=1000, units=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, errwidth=None, capsize=None, ax=None, **kwargs)

# %%
## countplot

# %%
sns.countplot(x='class', data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class', hue='who', data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
# countplot 完整参数列表
# seaborn.countplot(x=None, y=None, hue=None, data=None, order =None, hue_order=None, orient=None, color=None, palette=None , saturation=0.75, dodge=True, ax=None, **kwargs)
