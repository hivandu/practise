# %% [markdown]
# # different optimer

# %%
import numpy as np
import torch

# %%
x = np.random.random(size=(100, 8))

# %%
linear = torch.nn.Linear(in_features=8, out_features=1)
sigmoid = torch.nn.Sigmoid()
linear2 = torch.nn.Linear(in_features=1, out_features=1)

model = torch.nn.Sequential(linear, sigmoid, linear2).double()

# %%
train_x = torch.from_numpy(x)

print(model(train_x).shape)

yture = torch.from_numpy(np.random.uniform(0, 5, size=(100, 1)))

# print(x)
print(yture.shape)
# Out:
# torch.Size([100, 1])
# torch.Size([100, 1])

# %%
loss_fn = torch.nn.MSELoss()

optimer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
for e in range(100):
    for b in range(100 // 1): # stochastic gradient descent
    # for b in range(100 // 10): # mini-batch gradient descent
    # for b in range(100 // 100): # batch gradient descent
        batch_index = np.random.choice(range(len(train_x)), size=20)

        yhat = model(train_x[batch_index])
        loss = loss_fn(yhat, yture[batch_index])
        loss.backward()
        print(loss)
        optimer.step()
# Out:
# tensor(5.4533, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2662, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.8417, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.9389, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.1064, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5594, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6941, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.5031, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7659, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.6782, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.0438, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3395, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4141, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4416, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1933, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6128, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7717, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2107, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1987, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.5703, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.8644, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4191, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5889, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8817, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2491, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7147, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1376, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4699, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0229, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.1091, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.8681, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.6985, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0219, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.9757, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6198, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7621, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.6159, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5936, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2754, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.1672, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0826, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7195, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1737, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4718, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7954, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6689, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8442, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4375, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4213, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1216, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6974, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4215, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7961, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4988, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.5687, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.8859, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0294, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4958, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.5208, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.2408, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3710, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.5904, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6905, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.6145, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0735, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.9230, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5050, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.8938, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6398, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.3248, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0484, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1751, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.9455, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7034, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9471, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8690, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9779, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5297, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9618, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6767, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2406, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6632, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7327, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7789, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9611, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3511, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.7482, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1243, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3287, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0403, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.4417, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1231, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0720, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1630, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2029, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0273, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2988, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6955, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5777, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0313, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7844, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4353, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8926, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2662, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2680, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4009, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3495, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4024, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.9100, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3391, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5176, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1385, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7397, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2149, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4765, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7405, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.8019, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2656, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4434, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7860, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.1334, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(6.7460, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.9287, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8105, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4662, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7165, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.4968, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4596, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.8674, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4040, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1723, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7529, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8716, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4604, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5406, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2591, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3963, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.1619, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6065, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.2490, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.9874, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7492, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7953, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7327, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7820, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7835, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1354, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5875, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1992, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8060, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8634, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4457, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5916, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2875, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3716, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3990, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.6154, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7848, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7395, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0232, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3643, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0967, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0967, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8282, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.6329, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7532, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3222, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4651, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.2006, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7243, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6107, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4305, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8094, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3856, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5551, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3191, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9463, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.8997, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7782, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7911, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8947, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.1360, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.4041, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0031, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2996, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0035, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3797, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.5536, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.2089, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3040, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0062, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1694, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4374, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8508, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4344, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.2355, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0658, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2171, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3958, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.7280, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4373, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0929, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9133, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1598, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.9310, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7003, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.1002, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4138, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7856, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6849, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0415, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3576, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2873, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0048, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7964, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9895, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.
dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9142, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.1506, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9281, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7692, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0043, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6340, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2486, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7628, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0505, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6327, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3432, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8047, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8764, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5585, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4856, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3766, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0111, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7008, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0325, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.3163, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6510, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6739, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3224, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7006, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3120, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2607, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6857, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5384, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.8141, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3378, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9223, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6350, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7755, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2882, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0789, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3433, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9228, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9386, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8512, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7312, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1464, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2171, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3277, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1255, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7517, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4985, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.2903, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0035, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5608, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6282, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1378, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.3715, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7218, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6610, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3986, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0416, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.5419, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.1587, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0038, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9367, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8377, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3743, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.5628, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4248, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4240, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4692, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9341, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.5308, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.6726, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2687, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.6466, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1162, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5317, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7682, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0112, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2266, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8680, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0917, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7524, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6726, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1449, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.3545, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.9271, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.2489, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4900, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5131, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6774, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5032, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5643, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(5.0163, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.8219, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(4.0827, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3853, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5143, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3779, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8672, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7226, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7068, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6180, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8539, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.8731, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.0067, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.7472, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.4119, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.4360, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.7994, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.2873, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7180, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2471, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6008, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0864, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2088, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.1116, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9283, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.5002, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.8809, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.9299, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6337, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.3144, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.7274, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.2307, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.0090, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(3.6465, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.9578, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.6756, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(1.4298, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.8633, dtype=torch.float64, grad_fn=<MseLossBackward>)
# tensor(2.5439, dtype=torch.float64, grad_fn=<MseLossBackward>)

# %% [markdown]
# # Matrix dimension

# %%
from torch import nn
import torch
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1c7fd3ed0fd6> in <module>
# ----> 1 from torch import nn
#       2 import torch
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'

# %%
x = torch.from_numpy(np.random.random(size=(4, 10)))
print(x.shape)
# Out:
# torch.Size([4, 10])

# %%
model = nn.Sequential(
    nn.Linear(in_features=10, out_features=5).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Sigmoid(),
    nn.Linear(in_features=8, out_features=8).double(),
    nn.Softmax()
)

# %%
ytrue = torch.randint(8, (4, ))
print(ytrue)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5725bef876c6> in <module>
# ----> 1 ytrue = torch.randint(8, (4, ))
#       2 print(ytrue)
#
# NameError: name 'torch' is not defined

# %%
loss_fn = nn.CrossEntropyLoss()

print(model(x).shape)
print(ytrue.shape)
loss = loss_fn(model(x), ytrue)

print(torch.randint(5, (3, )))

loss.backward()

# %%
for p in model.parameters():
    print(p, p.grad)
