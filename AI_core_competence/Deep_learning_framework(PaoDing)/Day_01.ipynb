# %%
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
dir(dataset)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target']

# %%
print(dataset['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
dataset['data'].shape
# Out:
# (506, 13)

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame(dataset['data'])

# %%
dataframe.columns = dataset['feature_names']

# %%
dataframe
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
dataframe['price'] = dataset['target']

# %%
dataframe
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ## 地产销售: 买房子
#
# ### 看上了一个小区，想了解一个小区：犯罪率，房屋年龄，卧室数量

# %% [markdown]
# ## 有一天，你阅读了这503个记录！然后，有人找你买房子了解房价，那么，当他们说出来最关心的这三个特征的时，你怎么样能够估算出来，这个房子大约多少钱

# %% [markdown]
# # Data: 阅读了503条记录
# ## Input: (犯罪率，房屋年龄，卧室数量）Output: 估价？

# %% [markdown]
# ## 当年的时候，AI还处于幼年期的时候，当时用的方法很直接

# %%
important_features_data = dataframe[['CRIM', 'RM', 'AGE']]

# %%
important_features_data
# Out:
#         CRIM     RM   AGE
# 0    0.00632  6.575  65.2
# 1    0.02731  6.421  78.9
# 2    0.02729  7.185  61.1
# 3    0.03237  6.998  45.8
# 4    0.06905  7.147  54.2
# ..       ...    ...   ...
# 501  0.06263  6.593  69.1
# 502  0.04527  6.120  76.7
# 503  0.06076  6.976  91.0
# 504  0.10959  6.794  89.3
# 505  0.04741  6.030  80.8
#
# [506 rows x 3 columns]

# %%
features_to_price = dict()

# %%
house_age = dataframe['AGE']
house_rm = dataframe['RM']

# %%
price = dataframe['price']

# %%
house_rm_price = {a : p for a, p in zip(house_rm, price)}

# %%
house_rm_price
# Out:
# {6.575: 24.0,
#  6.421: 21.6,
#  7.185: 34.9,
#  6.998: 33.4,
#  7.147: 36.2,
#  6.43: 28.7,
#  6.012: 22.9,
#  6.172: 27.1,
#  5.631: 16.5,
#  6.004: 20.3,
#  6.377: 15.0,
#  6.009: 21.7,
#  5.889: 21.7,
#  5.949: 20.4,
#  6.096: 13.5,
#  5.834: 19.9,
#  5.935: 8.4,
#  5.99: 17.5,
#  5.456: 20.2,
#  5.727: 18.2,
#  5.57: 13.6,
#  5.965: 19.6,
#  6.142: 15.2,
#  5.813: 16.6,
#  5.924: 15.6,
#  5.599: 13.9,
#  6.047: 14.8,
#  6.495: 26.4,
#  6.674: 21.0,
#  5.713: 20.1,
#  6.072: 14.5,
#  5.95: 13.2,
#  5.701: 13.1,
#  5.933: 18.9,
#  5.841: 20.0,
#  5.85: 21.0,
#  5.966: 16.0,
#  6.595: 30.8,
#  7.024: 34.9,
#  6.77: 26.6,
#  6.169: 25.3,
#  6.211: 25.0,
#  6.069: 21.2,
#  5.682: 19.3,
#  5.786: 20.0,
#  6.03: 11.9,
#  5.399: 14.4,
#  5.602: 19.4,
#  5.963: 19.7,
#  6.115: 20.5,
#  6.511: 25.0,
#  5.998: 23.4,
#  5.888: 23.3,
#  7.249: 35.4,
#  6.383: 24.7,
#  6.816: 31.6,
#  6.145: 23.3,
#  5.927: 19.6,
#  5.741: 18.7,
#  6.456: 22.2,
#  6.762: 25.0,
#  7.104: 33.0,
#  6.29: 23.5,
#  5.787: 19.4,
#  5.878: 22.0,
#  5.594: 17.4,
#  5.885: 20.9,
#  6.417: 13.0,
#  5.961: 20.5,
#  6.065: 22.8,
#  6.245: 23.4,
#  6.273: 24.1,
#  6.286: 21.4,
#  6.279: 20.0,
#  6.14: 20.8,
#  6.232: 21.2,
#  5.874: 20.3,
#  6.727: 27.5,
#  6.619: 23.9,
#  6.302: 24.8,
#  6.167: 19.9,
#  6.389: 23.9,
#  6.63: 27.9,
#  6.015: 22.5,
#  6.121: 22.2,
#  7.007: 23.6,
#  7.079: 28.7,
#  6.405: 12.5,
#  6.442: 22.9,
#  6.249: 20.6,
#  6.625: 28.4,
#  6.163: 21.4,
#  8.069: 38.7,
#  7.82: 45.4,
#  7.416: 33.2,
#  6.781: 26.5,
#  6.137: 19.3,
#  5.851: 19.5,
#  5.836: 19.5,
#  6.127: 22.7,
#  6.474: 19.8,
#  6.229: 21.4,
#  6.195: 21.7,
#  6.715: 22.8,
#  5.913: 18.8,
#  6.092: 18.7,
#  6.254: 18.5,
#  5.928: 18.3,
#  6.176: 21.2,
#  6.021: 19.2,
#  5.872: 20.4,
#  5.731: 19.3,
#  5.87: 22.0,
#  5.856: 21.1,
#  5.879: 18.8,
#  5.986: 21.4,
#  5.613: 15.7,
#  5.693: 16.2,
#  6.431: 24.6,
#  5.637: 14.3,
#  6.458: 19.2,
#  6.326: 24.4,
#  6.372: 23.0,
#  5.822: 18.4,
#  5.757: 15.0,
#  6.335: 18.1,
#  5.942: 17.4,
#  6.454: 17.1,
#  5.857: 13.3,
#  6.151: 17.8,
#  6.174: 14.0,
#  5.019: 14.4,
#  5.403: 13.4,
#  5.468: 15.6,
#  4.903: 11.8,
#  6.13: 13.8,
#  5.628: 15.6,
#  4.926: 14.6,
#  5.186: 17.8,
#  5.597: 15.4,
#  6.122: 22.1,
#  5.404: 19.3,
#  5.012: 15.3,
#  5.709: 19.4,
#  6.129: 17.0,
#  6.152: 8.7,
#  5.272: 13.1,
#  6.943: 41.3,
#  6.066: 24.3,
#  6.51: 23.3,
#  6.25: 27.0,
#  7.489: 50.0,
#  7.802: 50.0,
#  8.375: 50.0,
#  5.854: 10.8,
#  6.101: 25.0,
#  7.929: 50.0,
#  5.877: 23.8,
#  6.319: 23.8,
#  6.402: 22.3,
#  5.875: 50.0,
#  5.88: 19.1,
#  5.572: 23.1,
#  6.416: 23.6,
#  5.859: 22.6,
#  6.546: 29.4,
#  6.02: 23.2,
#  6.315: 22.3,
#  6.86: 29.9,
#  6.98: 29.8,
#  7.765: 39.8,
#  6.144: 19.8,
#  7.155: 37.9,
#  6.563: 32.5,
#  5.604: 26.4,
#  6.153: 29.6,
#  7.831: 50.0,
#  6.782: 7.5,
#  6.556: 29.8,
#  6.951: 26.7,
#  6.739: 30.5,
#  7.178: 36.4,
#  6.8: 31.1,
#  6.604: 29.1,
#  7.875: 50.0,
#  7.287: 33.3,
#  7.107: 30.3,
#  7.274: 34.6,
#  6.975: 34.9,
#  7.135: 32.9,
#  6.162: 13.3,
#  7.61: 42.3,
#  7.853: 48.5,
#  8.034: 50.0,
#  5.891: 22.6,
#  5.783: 22.5,
#  6.064: 24.4,
#  5.344: 20.0,
#  5.96: 21.7,
#  5.807: 22.4,
#  6.375: 28.1,
#  5.412: 23.7,
#  6.182: 25.0,
#  6.642: 28.7,
#  5.951: 21.5,
#  6.373: 23.0,
#  6.164: 21.7,
#  6.879: 27.5,
#  6.618: 30.1,
#  8.266: 44.8,
#  8.725: 50.0,
#  8.04: 37.6,
#  7.163: 31.6,
#  7.686: 46.7,
#  6.552: 31.5,
#  5.981: 24.3,
#  7.412: 31.7,
#  8.337: 41.7,
#  8.247: 48.3,
#  6.726: 29.0,
#  6.086: 24.0,
#  6.631: 25.1,
#  7.358: 31.5,
#  6.481: 23.7,
#  6.606: 23.3,
#  6.897: 22.0,
#  6.095: 20.1,
#  6.358: 22.2,
#  6.393: 23.7,
#  5.593: 17.6,
#  5.605: 18.5,
#  6.108: 21.9,
#  6.226: 20.5,
#  6.433: 24.5,
#  6.718: 26.2,
#  6.487: 24.4,
#  6.438: 24.8,
#  6.957: 29.6,
#  8.259: 42.8,
#  5.876: 20.9,
#  7.454: 44.0,
#  8.704: 50.0,
#  7.333: 36.0,
#  6.842: 30.1,
#  7.203: 33.8,
#  7.52: 43.1,
#  8.398: 48.8,
#  7.327: 31.0,
#  7.206: 36.5,
#  5.56: 22.8,
#  7.014: 30.7,
#  8.297: 50.0,
#  7.47: 43.5,
#  5.92: 20.7,
#  6.24: 25.2,
#  6.538: 24.4,
#  7.691: 35.2,
#  6.758: 32.4,
#  6.854: 32.0,
#  7.267: 33.2,
#  6.826: 33.1,
#  6.482: 29.1,
#  6.812: 35.1,
#  6.968: 10.4,
#  7.645: 46.0,
#  7.923: 50.0,
#  7.088: 32.2,
#  6.453: 22.0,
#  6.23: 20.1,
#  6.209: 21.4,
#  6.565: 24.8,
#  6.861: 28.5,
#  7.148: 37.3,
#  6.678: 28.6,
#  6.549: 27.1,
#  5.79: 20.3,
#  6.345: 22.5,
#  7.041: 29.0,
#  6.871: 24.8,
#  6.59: 22.0,
#  6.982: 33.1,
#  7.236: 36.1,
#  6.616: 28.4,
#  7.42: 33.4,
#  6.849: 28.2,
#  6.635: 24.5,
#  5.972: 20.3,
#  4.973: 16.1,
#  6.023: 19.4,
#  6.266: 21.6,
#  6.567: 23.8,
#  5.705: 16.2,
#  5.914: 17.8,
#  5.782: 19.8,
#  6.382: 23.1,
#  6.113: 21.0,
#  6.426: 23.8,
#  6.376: 17.7,
#  6.041: 20.4,
#  5.708: 18.5,
#  6.415: 25.0,
#  6.312: 21.2,
#  6.083: 22.2,
#  5.868: 19.3,
#  6.333: 22.6,
#  5.706: 17.1,
#  6.031: 19.4,
#  6.316: 22.2,
#  6.31: 20.7,
#  6.037: 21.1,
#  5.869: 19.5,
#  5.895: 18.5,
#  6.059: 20.6,
#  5.985: 19.0,
#  5.968: 18.7,
#  7.241: 32.7,
#  6.54: 16.5,
#  6.696: 23.9,
#  6.874: 31.2,
#  6.014: 17.5,
#  5.898: 17.2,
#  6.516: 23.1,
#  6.939: 26.6,
#  6.49: 22.9,
#  6.579: 24.1,
#  5.884: 18.6,
#  6.728: 14.9,
#  5.663: 18.2,
#  5.936: 13.5,
#  6.212: 17.8,
#  6.395: 21.7,
#  6.112: 22.6,
#  6.398: 25.0,
#  6.251: 12.6,
#  5.362: 20.8,
#  5.803: 16.8,
#  8.78: 21.9,
#  3.561: 27.5,
#  4.963: 21.9,
#  3.863: 23.1,
#  4.97: 50.0,
#  6.683: 50.0,
#  7.016: 50.0,
#  6.216: 50.0,
#  4.906: 13.8,
#  4.138: 11.9,
#  7.313: 15.0,
#  6.649: 13.9,
#  6.794: 22.0,
#  6.38: 9.5,
#  6.223: 10.2,
#  6.545: 10.9,
#  5.536: 11.3,
#  5.52: 12.3,
#  4.368: 8.8,
#  5.277: 7.2,
#  4.652: 10.5,
#  5.0: 7.4,
#  4.88: 10.2,
#  5.39: 19.7,
#  6.051: 23.2,
#  5.036: 9.7,
#  6.193: 11.0,
#  5.887: 12.7,
#  6.471: 13.1,
#  5.747: 8.5,
#  5.453: 5.0,
#  5.852: 6.3,
#  5.987: 5.6,
#  6.343: 7.2,
#  6.404: 12.1,
#  5.349: 8.3,
#  5.531: 8.5,
#  5.683: 5.0,
#  5.608: 27.9,
#  5.617: 17.2,
#  6.852: 27.5,
#  6.657: 17.2,
#  4.628: 17.9,
#  5.155: 16.3,
#  4.519: 7.0,
#  6.434: 7.2,
#  5.304: 12.0,
#  5.957: 8.8,
#  6.824: 8.4,
#  6.411: 16.7,
#  6.006: 14.2,
#  5.648: 20.8,
#  6.103: 13.4,
#  5.565: 11.7,
#  5.896: 8.3,
#  5.837: 10.2,
#  6.202: 10.9,
#  6.348: 14.5,
#  6.833: 14.1,
#  6.425: 16.1,
#  6.436: 14.3,
#  6.208: 11.7,
#  6.629: 13.4,
#  6.461: 9.6,
#  5.627: 12.8,
#  5.818: 10.5,
#  6.406: 17.1,
#  6.219: 18.4,
#  6.485: 15.4,
#  6.459: 11.8,
#  6.341: 14.9,
#  6.185: 14.6,
#  6.749: 13.4,
#  6.655: 15.2,
#  6.297: 16.1,
#  7.393: 17.8,
#  6.525: 14.1,
#  5.976: 12.7,
#  6.301: 14.9,
#  6.081: 20.0,
#  6.701: 16.4,
#  6.317: 19.5,
#  6.513: 20.2,
#  5.759: 19.9,
#  5.952: 19.0,
#  6.003: 19.1,
#  5.926: 24.5,
#  6.437: 23.2,
#  5.427: 13.8,
#  6.484: 16.7,
#  6.242: 23.0,
#  6.75: 23.7,
#  7.061: 25.0,
#  5.762: 21.8,
#  5.871: 20.6,
#  6.114: 19.1,
#  5.905: 20.6,
#  5.454: 15.2,
#  5.414: 7.0,
#  5.093: 8.1,
#  5.983: 20.1,
#  5.707: 21.8,
#  5.67: 23.1,
#  5.794: 18.3,
#  6.019: 21.2,
#  5.569: 17.5,
#  6.027: 16.8,
#  6.593: 22.4,
#  6.12: 20.6,
#  6.976: 23.9}

# %%
sorted([(1, -1), (2, -3), (0, 9)], key=lambda t:t[1])
# Out:
# [(2, -3), (1, -1), (0, 9)]

# %%
import numpy as np

# %% [markdown]
# ## K-Nearest-Neighbors:KNN K近邻

# %%
def knn(query_age, data, top_n=3):
    most_similar = sorted(data.items(), key=lambda x_y: (x_y[0] - query_age)**2)[:top_n]
    print(most_similar)
    similary_ys = [y for x, y in most_similar]
    
    return np.mean(similary_ys)

# %%
house_rm_price[6.85]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/jd/jhbp58m554l8fyt81nfks5jm0000gn/T/ipykernel_75471/458256530.py in <module>
# ----> 1 house_rm_price[6.85]
#
# KeyError: 6.85

# %%
knn(6.85, house_rm_price)
# Out:
# [(6.849, 28.2), (6.852, 27.5), (6.854, 32.0)]
# 29.233333333333334

# %% [markdown]
# ## 到了2000年了，互联网，100万条数据，数据维度是200维度的

# %% [markdown]
# ## ??? 按照房屋年龄来估算，好像估算的不准~~~

# %%
import seaborn as sns

# %%
sns.heatmap(dataframe.corr(), annot=True, fmt='.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 定义一个函数，通过函数来预测房价

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dataframe['RM'], dataframe['price'])

# %% [markdown]
# ## LOSS

# %% [markdown]
# $$ loss(k, b) = \frac{1}{n} \sum_{i \in X}((y_i - (k * x_i + b))^2$$

# %%
import random

# %%
X_rm = dataframe['RM']
Y = dataframe['price']

# %%
def loss(k, b):
    return np.mean((Y - (k * X_rm + b))**2)

# %%
min_loss = float('inf')
best_k, best_b = None, None

for step in range(1000):
    k, b = random.randint(-100, 100), random.randint(-100, 100)
    current_loss = loss(k, b) 
    if current_loss < min_loss:
        min_loss = current_loss
        print('在第{}步，我得到了一个更好的Loss:{}，此时此刻，我的K和B是{}, {}'.format(step, min_loss, k, b))
        best_k, best_b = k, b
# Out:
# 在第0步，我得到了一个更好的Loss:32009.02211528063，此时此刻，我的K和B是-34, 60
# 在第4步，我得到了一个更好的Loss:961.0946035731224，此时此刻，我的K和B是-8, 45
# 在第37步，我得到了一个更好的Loss:950.225163541502，此时此刻，我的K和B是-4, 19
# 在第44步，我得到了一个更好的Loss:150.00065761264818，此时此刻，我的K和B是-4, 43
# 在第83步，我得到了一个更好的Loss:146.91646788932803，此时此刻，我的K和B是-4, 52
# 在第129步，我得到了一个更好的Loss:56.32242231620554，此时此刻，我的K和B是6, -18
# 在第891步，我得到了一个更好的Loss:51.82750534189723，此时此刻，我的K和B是7, -19

# %% [markdown]
# ## 蒙特卡洛模拟

# %%
plt.scatter(X_rm, Y)
plt.plot(X_rm, -10 * X_rm + 21)

# %%
plt.scatter(X_rm, Y)
plt.plot(X_rm, 1 * X_rm + 74)

# %%
plt.scatter(X_rm, Y)
plt.scatter(X_rm, 3 * X_rm + -3)

# %%
def partial_k(k, b, X, y):
    return 2 * np.mean((y - (k * X + b)) * (-X))

def partial_b(k, b, X, y):
     return 2 * np.mean((y - (k * X + b)) * (-1))

# %%
k = 10; b = -10

# %%
# k_history = []
# b_history = []

min_loss = float('inf')
best_k, best_b = None, None
k, b = random.randint(-50, 50), random.randint(-50, 50)
learning_rate = 1e-03
k_history = []
b_history = []

for step in range(1000):
    k, b = k + -1 * partial_k(k, b, X_rm, Y) * learning_rate, b + -1 * partial_b(k, b, X_rm, Y) * learning_rate
    current_loss = loss(k, b) 
    if current_loss < min_loss:
        min_loss = current_loss
        print('在第{}步，我得到了一个更好的Loss:{}，此时此刻，我的K和B是{}, {}'.format(step, min_loss, k, b))
        best_k, best_b = k, b
        k_history.append(k)
        b_history.append(b)
# Out:
# 在第0步，我得到了一个更好的Loss:55128.664842875005，此时此刻，我的K和B是-37.768055609774706, 27.506405632411067
# 在第1步，我得到了一个更好的Loss:46478.61575625828，此时此刻，我的K和B是-34.80096291466428, 27.971175275851675
# 在第2步，我得到了一个更好的Loss:39188.29035471524，此时此刻，我的K和B是-32.07701609991967, 28.3977211944411
# 在第3步，我得到了一个更好的Loss:33043.95007280599，此时此刻，我的K和B是-29.576288242200015, 28.789176001550825
# 在第4步，我得到了一个更好的Loss:27865.454475991937，此时此刻，我的K和B是-27.28048552123537, 29.14841557847026
# 在第5步，我得到了一个更好的Loss:23500.979881499825，此时此刻，我的K和B是-25.172813379514526, 29.478080114782358
# 在第6步，我得到了一个更好的Loss:19822.568173152864，此时此刻，我的K和B是-23.237853650802382, 29.780593424383586
# 在第7步，我得到了一个更好的Loss:16722.37530978148，此时此刻，我的K和B是-21.46145175854075, 30.058180678467203
# 在第8步，我得到了一个更好的Loss:14109.509540527784，此时此刻，我的K和B是-19.83061315885932, 30.31288468520692
# 在第9步，我得到了一个更好的Loss:11907.366629456088，此时此刻，我的K和B是-18.333408270558472, 30.546580835245603
# 在第10步，我得到了一个更好的Loss:10051.38396326097，此时此刻，我的K和B是-16.95888519651746, 30.760990822332356
# 在第11步，我得到了一个更好的Loss:8487.147696729948，此时此刻，我的K和B是-15.696989597984896, 30.95769523949028
# 在第12步，我得到了一个更好的Loss:7168.797441021536，此时此刻，我的K和B是-14.538491135539827, 31.13814514287032
# 在第13步，我得到了一个更好的Loss:6057.681723215962，此时此刻，我的K和B是-13.474915938554597, 31.30367266789405
# 在第14步，我得到了一个更好的Loss:5121.224797738276，此时此刻，我的K和B是-12.498484609095982, 31.45550077535471
# 在第15步，我得到了一个更好的Loss:4331.971586693602，此时此刻，我的K和B是-11.60205530669194, 31.594752198780444
# 在第16步，我得到了一个更好的Loss:3666.7827485593，此时此刻，我的K和B是-10.779071497563644, 31.722457658519893
# 在第17步，我得到了一个更好的Loss:3106.1562761601713，此时此刻，我的K和B是-10.02351398604841, 31.839563402645698
# 在第18步，我得到了一个更好的Loss:2633.6557344537828，此时此刻，我的K和B是-9.329856877268265, 31.94693812984627
# 在第19步，我得到了一个更好的Loss:2235.4283751318694，此时此刻，我的K和B是-8.693027148860482, 32.0453793449547
# 在第20步，我得到了一个更好的Loss:1899.7990000631564，此时此刻，我的K和B是-8.108367535990853, 32.13561919361284
# 在第21步，我得到了一个更好的Loss:1616.9276664167205，此时此刻，我的K和B是-7.5716024581109185, 32.21832981875779
# 在第22步，我得到了一个更好的Loss:1378.5211980231172，此时此刻，我的K和B是-7.078806738174251, 32.29412827811969
# 在第23步，我得到了一个更好的Loss:1177.5900450283248，此时此刻，我的K和B是-6.626376885456919, 32.36358105870797
# 在第24步，我得到了一个更好的Loss:1008.2433634223199，此时此刻，我的K和B是-6.211004731882966, 32.427208221314565
# 在第25步，我得到了一个更好的Loss:865.5163065590096，此时此刻，我的K和B是-5.829653228974341, 32.48548720535615
# 在第26步，我得到了一个更好的Loss:745.2244651793351，此时此刻，我的K和B是-5.479534228352169, 32.538856321891956
# 在第27步，我得到了一个更好的Loss:643.8411883924605，此时此刻，我的K和B是-5.15808808322819, 32.58771796037274
# 在第28步，我得到了一个更好的Loss:558.3941888966834，此时此刻，我的K和B是-4.8629649216478485, 32.63244153258191
# 在第29步，我得到了一个更好的Loss:486.37840109936946，此时此刻，我的K和B是-4.592007454477298, 32.67336617530711
# 在第30步，我得到了一个更好的Loss:425.6825372996946，此时此刻，我的K和B是-4.343235192354981, 32.710803231515484
# 在第31步，我得到了一个更好的Loss:374.52718869943953，此时此刻，我的K和B是-4.114829956136662, 32.745038528185134
# 在第32步，我得到了一个更好的Loss:331.412656479752，此时此刻，我的K和B是-3.9051225748261715, 32.77633446745787
# 在第33步，我得到了一个更好的Loss:295.0749834490551，此时此刻，我的K和B是-3.712580673671942, 32.80493194641233
# 在第34步，我得到了一个更好的Loss:264.4488971926092，此时此刻，我的K和B是-3.535797463085229, 32.83105211950288
# 在第35步，我得到了一个更好的Loss:238.6365782864912，此时此刻，我的K和B是-3.3734814463580776, 32.85489801655853
# 在第36步，我得到了一个更好的Loss:216.8813379186939，此时此刻，我的K和B是-3.22444697088117, 32.87665602817938
# 在第37步，我得到了一个更好的Loss:198.54543319464335，此时此刻，我的K和B是-3.087605553732848, 32.89649726939803
# 在第38步，我得到了一个更好的Loss:183.0913697135692，此时此刻，我的K和B是-2.961957918176039, 32.914578831582595
# 在第39步，我得到了一个更好的Loss:170.06614324239，此时此刻，我的K和B是-2.846586682800904, 32.931044931740566
# 在第40步，我得到了一个更好的Loss:159.08795848259504，此时此刻，我的K和B是-2.7406496498258903, 32.94602796763192
# 在第41步，我得到了一个更好的Loss:149.83503554931823，此时此刻，我的K和B是-2.6433736434534025, 32.95964948641084
# 在第42步，我得到了一个更好的Loss:142.03617598959704，此时此刻，我的K和B是-2.554048853200578, 32.97202107388277
# 在第43步，我得到了一个更好的Loss:135.46281175319413，此时此刻，我的K和B是-2.4720236408201406, 32.98324517088283
# 在第44步，我得到了一个更好的Loss:129.92230400674387，此时此刻，我的K和B是-2.396699772817986, 32.993415822748176
# 在第45步，我得到了一个更好的Loss:125.25229532504193，此时此刻，我的K和B是-2.327528043687894, 33.00261936736772
# 在第46步，我得到了一个更好的Loss:121.31594967633649，此时此刻，我的K和B是-2.2640042578422936, 33.01093506684298
# 在第47步，我得到了一个更好的Loss:117.99794064693262，此时此刻，我的K和B是-2.2056655408422983, 33.01843568738141
# 在第48步，我得到了一个更好的Loss:115.20107028739032，此时此刻，我的K和B是-2.1520869529394098, 33.02518803166482
# 在第49步，我得到了一个更好的Loss:112.84341945123938，此时此刻，我的K和B是-2.102878380153068, 33.031253427587735
# 在第50步，我得到了一个更好的Loss:110.85594607949523，此时此刻，我的K和B是-2.0576816801387015, 33.03668817694144
# 在第51步，我得到了一个更好的Loss:109.18046101718933，此时此刻，我的K和B是-2.016168061965024, 33.04154396732623
# 在第52步，我得到了一个更好的Loss:107.76792201665764，此时此刻，我的K和B是-1.9780356806306436, 33.04586825030561
# 在第53步，我得到了一个更好的Loss:106.57699591096792，此时此刻，我的K和B是-1.9430074287211014, 33.04970458856902
# 在第54步，我得到了一个更好的Loss:105.57284680311257，此时此刻，我的K和B是-1.910828909049782, 33.053092974642944
# 在第55步，我得到了一个更好的Loss:104.72611474294968，此时此刻，我的K和B是-1.8812665734502299, 33.0560701234822
# 在第56步，我得到了一个更好的Loss:104.01205494861956，此时此刻，我的K和B是-1.8541060141029997, 33.05866974108202
# 在第57步，我得到了一个更好的Loss:103.40981233602552，此时此刻，我的K和B是-1.8291503948961365, 33.060922771076136
# 在第58步，我得到了一个更好的Loss:102.90181008694566，此时此刻，我的K和B是-1.8062190113428822, 33.06285762112501
# 在第59步，我得到了一个更好的Loss:102.47323432974206，此时此刻，我的K和B是-1.785145968520753, 33.06450037075053
# 在第60步，我得到了一个更好的Loss:102.11159982447319，此时此刻，我的K和B是-1.765778967359594, 33.06587496213766
# 在第61步，我得到了一个更好的Loss:101.80638391911336，此时此刻，我的K和B是-1.7479781903989138, 33.06700337529907
# 在第62步，我得到了一个更好的Loss:101.54871804516299，此时此刻，我的K和B是-1.7316152788625316, 33.06790578888414
# 在第63步，我得到了一个更好的Loss:101.33112770788038，此时此刻，我的K和B是-1.7165723935666664, 33.068600727809
# 在第64步，我得到了一个更好的Loss:101.14731334813756，此时此刻，我的K和B是-1.7027413527909279, 33.069105198787575
# 在第65步，我得到了一个更好的Loss:100.99196565118068，此时此刻，我的K和B是-1.690022840804749, 33.069434814755255
# 在第66步，我得到了一个更好的Loss:100.8606098874958，此时此刻，我的K和B是-1.6783256812587188, 33.06960390909543
# 在第67步，我得到了一个更好的Loss:100.74947472214555，此时此刻，我的K和B是-1.6675661701248392, 33.06962564050469
# 在第68步，我得到了一个更好的Loss:100.65538164631366，此时此刻，我的K和B是-1.6576674633053978, 33.0695120892638
# 在第69步，我得到了一个更好的Loss:100.57565178939775，此时此刻，我的K和B是-1.6485590144301123, 33.069274345618865
# 在第70步，我得到了一个更好的Loss:100.50802737955587，此时此刻，我的K和B是-1.6401760587283851, 33.06892259091918
# 在第71步，我得到了一个更好的Loss:100.45060555007751，此时此刻，我的K和B是-1.6324591392006025, 33.06846617210555
# 在第72步，我得到了一个更好的Loss:100.40178255090669，此时此刻，我的K和B是-1.6253536716218764, 33.067913670093894
# 在第73步，我得到了一个更好的Loss:100.36020672970301，此时此刻，我的K和B是-1.6188095451957314, 33.0672729625545
# 在第74步，我得到了一个更好的Loss:100.32473890393462，此时此刻，我的K和B是-1.6127807559360592, 33.06655128154623
# 在第75步，我得到了一个更好的Loss:100.29441896218634，此时此刻，我的K和B是-1.6072250700951103, 33.06575526642739
# 在第76步，我得到了一个更好的Loss:100.26843771549704，此时此刻，我的K和B是-1.6021037151751094, 33.06489101243022
# 在第77步，我得到了一个更好的Loss:100.24611317345936，此时此刻，我的K和B是-1.5973810962628918, 33.06396411525457
# 在第78步，我得到了一个更好的Loss:100.22687054954244，此时此刻，我的K和B是-1.5930245356122212, 33.06297971200684
# 在第79步，我得到了一个更好的Loss:100.21022540943082，此时此刻，我的K和B是-1.5890040335685356, 33.06194251878386
# 在第80步，我得到了一个更好的Loss:100.19576946832044，此时此刻，我的K和B是-1.5852920490870093, 33.060856865176525
# 在第81步，我得到了一个更好的Loss:100.18315862077537，此时此刻，我的K和B是-1.581863298238171, 33.05972672594577
# 在第82步，我得到了一个更好的Loss:100.17210285220311，此时此刻，我的K和B是-1.578694569226914, 33.0585557501025
# 在第83步，我得到了一个更好的Loss:100.16235773617163，此时此刻，我的K和B是-1.575764552571548, 33.057347287604294
# 在第84步，我得到了一个更好的Loss:100.15371726828587，此时此刻，我的K和B是-1.5730536852004604, 33.056104413864226
# 在第85步，我得到了一个更好的Loss:100.14600782652589，此时此刻，我的K和B是-1.5705440073257744, 33.05482995225104
# 在第86步，我得到了一个更好的Loss:100.13908308097574，此时此刻，我的K和B是-1.5682190310468678, 33.053526494745334
# 在第87步，我得到了一个更好的Loss:100.13281970370528，此时此刻，我的K和B是-1.5660636197224391, 33.052196420902895
# 在第88步，我得到了一个更好的Loss:100.12711375302727，此时此刻，我的K和B是-1.5640638772285878, 33.05084191526389
# 在第89步，我得到了一个更好的Loss:100.12187762612234，此时此刻，我的K和B是-1.562207046292704, 33.04946498333527
# 在第90步，我得到了一个更好的Loss:100.11703749068931，此时此刻，我的K和B是-1.5604814151593656, 33.04806746626341
# 在第91步，我得到了一个更好的Loss:100.11253112032081，此时此刻，我的K和B是-1.5588762319053913, 33.04665105430417
# 在第92步，我得到了一个更好的Loss:100.10830607014218，此时此刻，我的K和B是-1.557381625777173, 33.0452172991891
# 在第93步，我得到了一个更好的Loss:100.10431813922652，此时此刻，我的K和B是-1.555988534974774, 33.04376762547812
# 在第94步，我得到了一个更好的Loss:100.10053007470655，此时此刻，我的K和B是-1.5546886403544513, 33.04230334098184
# 在第95步，我得到了一个更好的Loss:100.09691047959092，此时此刻，我的K和B是-1.5534743045645651, 33.04082564632969
# 在第96步，我得到了一个更好的Loss:100.09343289226342，此时此刻，我的K和B是-1.5523385161695764, 33.039335643753915
# 在第97步，我得到了一个更好的Loss:100.09007501067836，此时此刻，我的K和B是-1.5512748383533435, 33.03783434515369
# 在第98步，我得到了一个更好的Loss:100.08681803850664，此时此刻，我的K和B是-1.550277361826417, 33.036322679498305
# 在第99步，我得到了一个更好的Loss:100.08364613406297，此时此刻，我的K和B是-1.5493406615928003, 33.03480149962366
# 在第100步，我得到了一个更好的Loss:100.08054594585744，此时此刻，我的K和B是-1.5484597572598724, 33.03327158847177
# 在第101步，我得到了一个更好的Loss:100.07750622115525，此时此刻，我的K和B是-1.5476300766010949, 33.03173366481886
# 在第102步，我得到了一个更好的Loss:100.07451747606774，此时此刻，我的K和B是-1.5468474221049233, 33.03018838853406
# 在第103步，我得到了一个更好的Loss:100.07157171750288，此时此刻，我的K和B是-1.5461079402651892, 33.0286363654071
# 在第104步，我得到了一个更好的Loss:100.06866220882289，此时此刻，我的K和B是-1.545408093388276, 33.027078151580405
# 在第105步，我得到了一个更好的Loss:100.06578327233895，此时此刻，我的K和B是-1.544744633710827, 33.025514257617864
# 在第106步，我得到了一个更好的Loss:100.06293012285225，此时此刻，我的K和B是-1.5441145796386273, 33.023945152240245
# 在第107步，我得到了一个更好的Loss:100.06009872736094，此时此刻，我的K和B是-1.5435151939328164, 33.0223712657544
# 在第108步，我得到了一个更好的Loss:100.0572856868205，此时此刻，我的K和B是-1.5429439636838433, 33.020792993201496
# 在第109步，我得到了一个更好的Loss:100.05448813649024，此时此刻，我的K和B是-1.5423985819266468, 33.01921069724716
# 在第110步，我得到了一个更好的Loss:100.05170366194461，此时此刻，我的K和B是-1.5418769307625566, 33.017624710834845
# 在第111步，我得到了一个更好的Loss:100.04893022828705，此时此刻，我的K和B是-1.5413770658644332, 33.016035339621666
# 在第112步，我得到了一个更好的Loss:100.04616612049075，此时此刻，我的K和B是-1.540897202251682, 33.01444286421466
# 在第113步，我得到了一个更好的Loss:100.04340989311754，此时此刻，我的K和B是-1.5404357012310699, 33.01284754222374
# 在第114步，我得到了一个更好的Loss:100.04066032794054，此时此刻，我的K和B是-1.5399910584078036, 33.011249610146436
# 在第115步，我得到了一个更好的Loss:100.03791639822818，此时此刻，我的K和B是-1.539561892679154, 33.009649285098135
# 在第116步，我得到了一个更好的Loss:100.03517723864249，此时此刻，我的K和B是-1.5391469361301051, 33.00804676640053
# 在第117步，我得到了一个更好的Loss:100.03244211986942，此时此刻，我的K和B是-1.538745024757098, 33.006442237039934
# 在第118步，我得到了一个更好的Loss:100.0297104272366，此时此刻，我的K和B是-1.5383550899520109, 33.00483586500599
# 在第119步，我得到了一个更好的Loss:100.02698164269268，此时此刻，我的K和B是-1.537976150684063, 33.00322780452073
# 在第120步，我得到了一个更好的Loss:100.02425532961928，此时此刻，我的K和B是-1.5376073063224485, 33.00161819716695
# 在第121步，我得到了一个更好的Loss:100.02153112003012，此时此刻，我的K和B是-1.5372477300471885, 33.00000717292395
# 在第122步，我得到了一个更好的Loss:100.01880870378272，此时此刻，我的K和B是-1.5368966627999945, 32.99839485111859
# 在第123步，我得到了一个更好的Loss:100.01608781948575，此时此刻，我的K和B是-1.5365534077308858, 32.99678134129825
# 在第124步，我得到了一个更好的Loss:100.01336824683563，此时此刻，我的K和B是-1.536217325099932, 32.99516674403233
# 在第125步，我得到了一个更好的Loss:100.01064980015795，此时此刻，我的K和B是-1.5358878275968226, 32.99355115164803
# 在第126步，我得到了一个更好的Loss:100.00793232296397，此时此刻，我的K和B是-1.5355643760440172, 32.99193464890581
# 在第127步，我得到了一个更好的Loss:100.00521568336279，此时此刻，我的K和B是-1.535246475452044, 32.99031731361958
# 在第128步，我得到了一个更好的Loss:100.00249977019483，此时此刻，我的K和B是-1.5349336713980846, 32.988699217225935
# 在第129步，我得到了一个更好的Loss:99.99978448977305，此时此刻，我的K和B是-1.5346255467013492, 32.98708042530685
# 在第130步，我得到了一个更好的Loss:99.99706976313618，此时此刻，我的K和B是-1.534321718370922, 32.98546099806947
# 在第131步，我得到了一个更好的Loss:99.99435552373431，此时此刻，我的K和B是-1.5340218348037424, 32.983840990786625
# 在第132步，我得到了一个更好的Loss:99.99164171547753，此时此刻，我的K和B是-1.5337255732122275, 32.98222045420118
# 在第133步，我得到了一个更好的Loss:99.98892829109195，此时此刻，我的K和B是-1.5334326372627094, 32.98059943489734
# 在第134步，我得到了一个更好的Loss:99.98621521073379，此时此刻，我的K和B是-1.5331427549074161, 32.97897797564143
# 在第135步，我得到了一个更好的Loss:99.98350244082135，此时此刻，我的K和B是-1.5328556763941308, 32.97735611569479
# 在第136步，我得到了一个更好的Loss:99.9807899530509，此时此刻，我的K和B是-1.5325711724389672, 32.97573389110105
# 在第137步，我得到了一个更好的Loss:99.97807772356673，此时此刻，我的K和B是-1.5322890325488976, 32.97411133494982
# 在第138步，我得到了一个更好的Loss:99.97536573226212，此时此刻，我的K和B是-1.5320090634817536, 32.972488477618775
# 在第139步，我得到了一个更好的Loss:99.97265396219004，此时此刻，我的K和B是-1.53173108783244, 32.97086534699594
# 在第140步，我得到了一个更好的Loss:99.96994239906634，此时此刻，我的K和B是-1.5314549427350135, 32.969241968683704
# 在第141步，我得到了一个更好的Loss:99.96723103085134，此时此刻，我的K和B是-1.531180478671132, 32.967618366186144
# 在第142步，我得到了一个更好的Loss:99.96451984739686，此时此刻，我的K和B是-1.530907558376158, 32.96599456108099
# 在第143步，我得到了一个更好的Loss:99.96180884014898，此时此刻，我的K和B是-1.5306360558349101, 32.964370573177504
# 在第144步，我得到了一个更好的Loss:99.95909800189737，此时此刻，我的K和B是-1.5303658553597193, 32.96274642066141
# 在第145步，我得到了一个更好的Loss:99.95638732656418，此时此刻，我的K和B是-1.530096850744041, 32.961122120227955
# 在第146步，我得到了一个更好的Loss:99.95367680902595，此时此刻，我的K和B是-1.5298289444854334, 32.95949768720405
# 在第147步，我得到了一个更好的Loss:99.95096644496361，此时此刻，我的K和B是-1.5295620470722169, 32.95787313566042
# 在第148步，我得到了一个更好的Loss:99.94825623073595，此时此刻，我的K和B是-1.5292960763285937, 32.95624847851456
# 在第149步，我得到了一个更好的Loss:99.94554616327329，此时此刻，我的K和B是-1.5290309568134384, 32.954623727625226
# 在第150步，我得到了一个更好的Loss:99.94283623998739，此时此刻，我的K和B是-1.528766619268361, 32.952998893879226
# 在第151步，我得到了一个更好的Loss:99.94012645869593，此时此刻，我的K和B是-1.5285030001110038, 32.95137398727107
# 在第152步，我得到了一个更好的Loss:99.93741681755859，此时此刻，我的K和B是-1.5282400409698629, 32.949749016976085
# 在第153步，我得到了一个更好的Loss:99.93470731502343，此时此刻，我的K和B是-1.527977688257236, 32.94812399141757
# 在第154步，我得到了一个更好的Loss:99.9319979497814，此时此刻，我的K和B是-1.5277158927771675, 32.94649891832841
# 在第155步，我得到了一个更好的Loss:99.9292887207283，此时此刻，我的K和B是-1.5274546093655248, 32.94487380480768
# 在第156步，我得到了一个更好的Loss:99.92657962693247，此时此刻，我的K和B是-1.5271937965595714, 32.94324865737256
# 在第157步，我得到了一个更好的Loss:99.92387066760777，此时此刻，我的K和B是-1.526933416294621, 32.94162348200605
# 在第158步，我得到了一个更好的Loss:99.92116184209058，此时此刻，我的K和B是-1.5266734336255516, 32.93999828420074
# 在第159步，我得到了一个更好的Loss:99.9184531498207，此时此刻，我的K和B是-1.526413816471142, 32.938373068999
# 在第160步，我得到了一个更好的Loss:99.91574459032489，此时此刻，我的K和B是-1.5261545353793633, 32.93674784102987
# 在第161步，我得到了一个更好的Loss:99.91303616320343，此时此刻，我的K和B是-1.5258955633119033, 32.93512260454295
# 在第162步，我得到了一个更好的Loss:99.9103278681184，此时此刻，我的K和B是-1.5256368754463523, 32.93349736343948
# 在第163步，我得到了一个更好的Loss:99.90761970478397，此时此刻，我的K和B是-1.5253784489945985, 32.931872121300906
# 在第164步，我得到了一个更好的Loss:99.90491167295832，此时此刻，我的K和B是-1.5251202630361094, 32.93024688141508
# 在第165步，我得到了一个更好的Loss:99.90220377243665，此时此刻，我的K和B是-1.5248622983648736, 32.928621646800316
# 在第166步，我得到了一个更好的Loss:99.89949600304534，此时此刻，我的K和B是-1.524604537348889, 32.926996420227496
# 在第167步，我得到了一个更好的Loss:99.8967883646371，此时此刻，我的K和B是-1.524346963801165, 32.925371204240335
# 在第168步，我得到了一个更好的Loss:99.89408085708678，此时此刻，我的K和B是-1.5240895628612976, 32.923746001173996
# 在第169步，我得到了一个更好的Loss:99.891373480288，此时此刻，我的K和B是-1.5238323208867486, 32.92212081317219
# 在第170步，我得到了一个更好的Loss:99.88866623414997，此时此刻，我的K和B是-1.523575225353037, 32.92049564220287
# 在第171步，我得到了一个更好的Loss:99.88595911859532，此时此刻，我的K和B是-1.5233182647621082, 32.91887049007263
# 在第172步，我得到了一个更好的Loss:99.88325213355783，此时此刻，我的K和B是-1.523061428558214, 32.917245358439914
# 在第173步，我得到了一个更好的Loss:99.88054527898066，此时此刻，我的K和B是-1.5228047070506865, 32.91562024882719
# 在第174步，我得到了一个更好的Loss:99.87783855481497，此时此刻，我的K和B是-1.5225480913430403, 32.91399516263206
# 在第175步，我得到了一个更好的Loss:99.87513196101855，此时此刻，我的K和B是-1.522291573267886, 32.91237010113752
# 在第176步，我得到了一个更好的Loss:99.87242549755491，此时此刻，我的K和B是-1.5220351453271768, 32.91074506552133
# 在第177步，我得到了一个更好的Loss:99.86971916439232，此时此刻，我的K和B是-1.5217788006373538, 32.90912005686467
# 在第178步，我得到了一个更好的Loss:99.86701296150298，此时此刻，我的K和B是-1.5215225328789852, 32.907495076160025
# 在第179步，我得到了一个更好的Loss:99.86430688886252，此时此刻，我的K和B是-1.5212663362505332, 32.90587012431845
# 在第180步，我得到了一个更好的Loss:99.8616009464494，此时此刻，我的K和B是-1.5210102054259111, 32.90424520217627
# 在第181步，我得到了一个更好的Loss:99.85889513424455，此时此刻，我的K和B是-1.5207541355155172, 32.902620310501206
# 在第182步，我得到了一个更好的Loss:99.8561894522308，此时此刻，我的K和B是-1.5204981220304632, 32.900995449997964
# 在第183步，我得到了一个更好的Loss:99.85348390039277，此时此刻，我的K和B是-1.5202421608497334, 32.89937062131342
# 在第184步，我得到了一个更好的Loss:99.8507784787165，此时此刻，我的K和B是-1.5199862481900366, 32.897745825041376
# 在第185步，我得到了一个更好的Loss:99.84807318718924，此时此刻，我的K和B是-1.5197303805781275, 32.896121061726866
# 在第186步，我得到了一个更好的Loss:99.84536802579926，此时此刻，我的K和B是-1.519474554825397, 32.8944963318702
# 在第187步，我得到了一个更好的Loss:99.84266299453573，此时此刻，我的K和B是-1.519218768004545, 32.892871635930604
# 在第188步，我得到了一个更好的Loss:99.83995809338845，此时此刻，我的K和B是-1.5189630174281654, 32.89124697432959
# 在第189步，我得到了一个更好的Loss:99.83725332234789，此时此刻，我的K和B是-1.518707300629085, 32.88962234745404
# 在第190步，我得到了一个更好的Loss:99.83454868140508，此时此刻，我的K和B是-1.5184516153423149, 32.88799775565907
# 在第191步，我得到了一个更好的Loss:99.83184417055136，此时此刻，我的K和B是-1.5181959594884802, 32.886373199270594
# 在第192步，我得到了一个更好的Loss:99.82913978977858，此时此刻，我的K和B是-1.5179403311586082, 32.884748678587755
# 在第193步，我得到了一个更好的Loss:99.8264355390788，此时此刻，我的K和B是-1.5176847286001633, 32.883124193885095
# 在第194步，我得到了一个更好的Loss:99.8237314184444，此时此刻，我的K和B是-1.5174291502042263, 32.88149974541459
# 在第195步，我得到了一个更好的Loss:99.82102742786793，此时此刻，我的K和B是-1.517173594493724, 32.87987533340747
# 在第196步，我得到了一个更好的Loss:99.81832356734213，此时此刻，我的K和B是-1.516918060112624, 32.87825095807595
# 在第197步，我得到了一个更好的Loss:99.81561983685994，此时此刻，我的K和B是-1.516662545816015, 32.87662661961478
# 在第198步，我得到了一个更好的Loss:99.8129162364144，此时此刻，我的K和B是-1.516407050461, 32.87500231820266
# 在第199步，我得到了一个更好的Loss:99.81021276599863，此时此刻，我的K和B是-1.5161515729983355, 32.873378054003574
# 在第200步，我得到了一个更好的Loss:99.80750942560593，此时此刻，我的K和B是-1.5158961124647556, 32.87175382716799
# 在第201步，我得到了一个更好的Loss:99.80480621522958，此时此刻，我的K和B是-1.5156406679759273, 32.870129637833976
# 在第202步，我得到了一个更好的Loss:99.802103134863，此时此刻，我的K和B是-1.5153852387199802, 32.86850548612819
# 在第203步，我得到了一个更好的Loss:99.79940018449963，此时此刻，我的K和B是-1.5151298239515685, 32.866881372166844
# 在第204步，我得到了一个更好的Loss:99.79669736413297，此时此刻，我的K和B是-1.5148744229864184, 32.86525729605655
# 在第205步，我得到了一个更好的Loss:99.79399467375653，此时此刻，我的K和B是-1.514619035196324, 32.863633257895096
# 在第206步，我得到了一个更好的Loss:99.79129211336391，此时此刻，我的K和B是-1.5143636600045511, 32.86200925777219
# 在第207步，我得到了一个更好的Loss:99.78858968294873，此时此刻，我的K和B是-1.51410829688162, 32.86038529577011
# 在第208步，我得到了一个更好的Loss:99.78588738250454，此时此刻，我的K和B是-1.5138529453414316, 32.858761371964306
# 在第209步，我得到了一个更好的Loss:99.78318521202505，此时此刻，我的K和B是-1.5135976049377133, 32.85713748642397
# 在第210步，我得到了一个更好的Loss:99.78048317150387，此时此刻，我的K和B是-1.5133422752607542, 32.85551363921255
# 在第211步，我得到了一个更好的Loss:99.7777812609347，此时此刻，我的K和B是-1.513086955934409, 32.853889830388226
# 在第212步，我得到了一个更好的Loss:99.77507948031123，此时此刻，我的K和B是-1.5128316466133471, 32.85226606000431
# 在第213步，我得到了一个更好的Loss:99.77237782962715，此时此刻，我的K和B是-1.5125763469805276, 32.850642328109686
# 在第214步，我得到了一个更好的Loss:99.76967630887616，此时此刻，我的K和B是-1.51232105674488, 32.84901863474914
# 在第215步，我得到了一个更好的Loss:99.76697491805197，此时此刻，我的K和B是-1.5120657756391764, 32.84739497996374
# 在第216步，我得到了一个更好的Loss:99.7642736571483，此时此刻，我的K和B是-1.5118105034180778, 32.84577136379107
# 在第217步，我得到了一个更好的Loss:99.76157252615889，此时此刻，我的K和B是-1.511555239856339, 32.844147786265594
# 在第218步，我得到了一个更好的Loss:99.75887152507747，此时此刻，我的K和B是-1.511299984747163, 32.84252424741885
# 在第219步，我得到了一个更好的Loss:99.75617065389773，此时此刻，我的K和B是-1.511044737900689, 32.840900747279726
# 在第220步，我得到了一个更好的Loss:99.75346991261345，此时此刻，我的K和B是-1.5107894991426034, 32.839277285874665
# 在第221步，我得到了一个更好的Loss:99.75076930121836，此时此刻，我的K和B是-1.5105342683128669, 32.837653863227864
# 在第222步，我得到了一个更好的Loss:99.7480688197062，此时此刻，我的K和B是-1.5102790452645436, 32.836030479361455
# 在第223步，我得到了一个更好的Loss:99.74536846807072，此时此刻，我的K和B是-1.510023829862728, 32.83440713429569
# 在第224步，我得到了一个更好的Loss:99.74266824630563，此时此刻，我的K和B是-1.5097686219835582, 32.83278382804907
# 在第225步，我得到了一个更好的Loss:99.73996815440472，此时此刻，我的K和B是-1.5095134215133117, 32.831160560638516
# 在第226步，我得到了一个更好的Loss:99.73726819236171，此时此刻，我的K和B是-1.5092582283475737, 32.82953733207948
# 在第227步，我得到了一个更好的Loss:99.73456836017039，此时此刻，我的K和B是-1.5090030423904746, 32.82791414238608
# 在第228步，我得到了一个更好的Loss:99.73186865782444，此时此刻，我的K和B是-1.5087478635539897, 32.82629099157118
# 在第229步，我得到了一个更好的Loss:99.72916908531768，此时此刻，我的K和B是-1.5084926917572963, 32.824667879646526
# 在第230步，我得到了一个更好的Loss:99.72646964264383，此时此刻，我的K和B是-1.5082375269261834, 32.823044806622825
# 在第231步，我得到了一个更好的Loss:99.72377032979665，此时此刻，我的K和B是-1.5079823689925098, 32.82142177250983
# 在第232步，我得到了一个更好的Loss:99.7210711467699，此时此刻，我的K和B是-1.5077272178937067, 32.819798777316414
# 在第233步，我得到了一个更好的Loss:99.71837209355732，此时此刻，我的K和B是-1.507472073572321, 32.818175821050644
# 在第234步，我得到了一个更好的Loss:99.7156731701527，此时此刻，我的K和B是-1.5072169359755963, 32.81655290371985
# 在第235步，我得到了一个更好的Loss:99.71297437654977，此时此刻，我的K和B是-1.5069618050550873, 32.814930025330696
# 在第236步，我得到了一个更好的Loss:99.71027571274224，此时此刻，我的K和B是-1.5067066807663072, 32.81330718588921
# 在第237步，我得到了一个更好的Loss:99.70757717872395，此时此刻，我的K和B是-1.506451563068403, 32.811684385400845
# 在第238步，我得到了一个更好的Loss:99.70487877448862，此时此刻，我的K和B是-1.5061964519238575, 32.810061623870546
# 在第239步，我得到了一个更好的Loss:99.70218050003，此时此刻，我的K和B是-1.5059413472982166, 32.808438901302765
# 在第240步，我得到了一个更好的Loss:99.69948235534187，此时此刻，我的K和B是-1.5056862491598373, 32.80681621770151
# 在第241步，我得到了一个更好的Loss:99.69678434041793，此时此刻，我的K和B是-1.5054311574796577, 32.80519357307039
# 在第242步，我得到了一个更好的Loss:99.69408645525205，此时此刻，我的K和B是-1.5051760722309862, 32.80357096741265
# 在第243步，我得到了一个更好的Loss:99.69138869983786，此时此刻，我的K和B是-1.5049209933893062, 32.80194840073116
# 在第244步，我得到了一个更好的Loss:99.68869107416921，此时此刻，我的K和B是-1.504665920932098, 32.80032587302853
# 在第245步，我得到了一个更好的Loss:99.68599357823983，此时此刻，我的K和B是-1.504410854838676, 32.798703384307025
# 在第246步，我得到了一个更好的Loss:99.68329621204349，此时此刻，我的K和B是-1.5041557950900377, 32.79708093456868
# 在第247步，我得到了一个更好的Loss:99.68059897557393，此时此刻，我的K和B是-1.5039007416687256, 32.795458523815284
# 在第248步，我得到了一个更好的Loss:99.67790186882493，此时此刻，我的K和B是-1.5036456945587007, 32.793836152048385
# 在第249步，我得到了一个更好的Loss:99.67520489179024，此时此刻，我的K和B是-1.5033906537452266, 32.79221381926934
# 在第250步，我得到了一个更好的Loss:99.67250804446363，此时此刻，我的K和B是-1.5031356192147627, 32.79059152547933
# 在第251步，我得到了一个更好的Loss:99.66981132683884，此时此刻，我的K和B是-1.502880590954866, 32.78896927067933
# 在第252步，我得到了一个更好的Loss:99.66711473890966，此时此刻，我的K和B是-1.5026255689541006, 32.78734705487019
# 在第253步，我得到了一个更好的Loss:99.66441828066985，此时此刻，我的K和B是-1.5023705532019564, 32.7857248780526
# 在第254步，我得到了一个更好的Loss:99.66172195211315，此时此刻，我的K和B是-1.5021155436887725, 32.78410274022711
# 在第255步，我得到了一个更好的Loss:99.65902575323335，此时此刻，我的K和B是-1.5018605404056675, 32.782480641394166
# 在第256步，我得到了一个更好的Loss:99.65632968402419，此时此刻，我的K和B是-1.5016055433444757, 32.78085858155408
# 在第257步，我得到了一个更好的Loss:99.65363374447945，此时此刻，我的K和B是-1.5013505524976887, 32.77923656070707
# 在第258步，我得到了一个更好的Loss:99.65093793459289，此时此刻，我的K和B是-1.5010955678584013, 32.77761457885327
# 在第259步，我得到了一个更好的Loss:99.64824225435827，此时此刻，我的K和B是-1.500840589420262, 32.77599263599271
# 在第260步，我得到了一个更好的Loss:99.64554670376934，此时此刻，我的K和B是-1.5005856171774283, 32.77437073212535
# 在第261步，我得到了一个更好的Loss:99.6428512828199，此时此刻，我的K和B是-1.5003306511245236, 32.772748867251075
# 在第262步，我得到了一个更好的Loss:99.6401559915037，此时此刻，我的K和B是-1.5000756912566005, 32.7711270413697
# 在第263步，我得到了一个更好的Loss:99.63746082981449，此时此刻，我的K和B是-1.4998207375691046, 32.76950525448099
# 在第264步，我得到了一个更好的Loss:99.63476579774606，此时此刻，我的K和B是-1.4995657900578432, 32.76788350658463
# 在第265步，我得到了一个更好的Loss:99.63207089529216，此时此刻，我的K和B是-1.4993108487189546, 32.76626179768027
# 在第266步，我得到了一个更好的Loss:99.62937612244656，此时此刻，我的K和B是-1.4990559135488817, 32.764640127767514
# 在第267步，我得到了一个更好的Loss:99.62668147920303，此时此刻，我的K和B是-1.4988009845443468, 32.7630184968459
# 在第268步，我得到了一个更好的Loss:99.62398696555532，此时此刻，我的K和B是-1.498546061702329, 32.76139690491496
# 在第269步，我得到了一个更好的Loss:99.62129258149723，此时此刻，我的K和B是-1.4982911450200425, 32.75977535197416
# 在第270步，我得到了一个更好的Loss:99.6185983270225，此时此刻，我的K和B是-1.4980362344949179, 32.75815383802295
# 在第271步，我得到了一个更好的Loss:99.6159042021249，此时此刻，我的K和B是-1.4977813301245841, 32.756532363060735
# 在第272步，我得到了一个更好的Loss:99.61321020679821，此时此刻，我的K和B是-1.4975264319068529, 32.754910927086904
# 在第273步，我得到了一个更好的Loss:99.61051634103619，此时此刻，我的K和B是-1.4972715398397025, 32.75328953010081
# 在第274步，我得到了一个更好的Loss:99.6078226048326，此时此刻，我的K和B是-1.4970166539212653, 32.75166817210179
# 在第275步，我得到了一个更好的Loss:99.60512899818127，此时此刻，我的K和B是-1.4967617741498145, 32.75004685308915
# 在第276步，我得到了一个更好的Loss:99.60243552107586，此时此刻，我的K和B是-1.4965069005237528, 32.748425573062185
# 在第277步，我得到了一个更好的Loss:99.59974217351024，此时此刻，我的K和B是-1.4962520330416016, 32.74680433202016
# 在第278步，我得到了一个更好的Loss:99.59704895547812，此时此刻，我的K和B是-1.4959971717019915, 32.74518312996234
# 在第279步，我得到了一个更好的Loss:99.59435586697332，此时此刻，我的K和B是-1.4957423165036532, 32.74356196688796
# 在第280步，我得到了一个更好的Loss:99.59166290798954，此时此刻，我的K和B是-1.4954874674454095, 32.74194084279624
# 在第281步，我得到了一个更好的Loss:99.58897007852062，此时此刻，我的K和B是-1.4952326245261673, 32.74031975768639
# 在第282步，我得到了一个更好的Loss:99.58627737856028，此时此刻，我的K和B是-1.4949777877449115, 32.73869871155762
# 在第283步，我得到了一个更好的Loss:99.58358480810232，此时此刻，我的K和B是-1.4947229571006977, 32.7370777044091
# 在第284步，我得到了一个更好的Loss:99.58089236714052，此时此刻，我的K和B是-1.4944681325926468, 32.735456736240025
# 在第285步，我得到了一个更好的Loss:99.57820005566862，此时此刻，我的K和B是-1.4942133142199399, 32.73383580704955
# 在第286步，我得到了一个更好的Loss:99.57550787368042，此时此刻，我的K和B是-1.493958501981813, 32.732214916836845
# 在第287步，我得到了一个更好的Loss:99.57281582116968，此时此刻，我的K和B是-1.4937036958775527, 32.73059406560105
# 在第288步，我得到了一个更好的Loss:99.57012389813016，此时此刻，我的K和B是-1.493448895906492, 32.72897325334132
# 在第289步，我得到了一个更好的Loss:99.56743210455566，此时此刻，我的K和B是-1.4931941020680064, 32.727352480056794
# 在第290步，我得到了一个更好的Loss:99.56474044043995，此时此刻，我的K和B是-1.4929393143615106, 32.7257317457466
# 在第291步，我得到了一个更好的Loss:99.56204890577679，此时此刻，我的K和B是-1.4926845327864553, 32.72411105040986
# 在第292步，我得到了一个更好的Loss:99.55935750055997，此时此刻，我的K和B是-1.492429757342324, 32.7224903940457
# 在第293步，我得到了一个更好的Loss:99.55666622478326，此时此刻，我的K和B是-1.4921749880286306, 32.72086977665323
# 在第294步，我得到了一个更好的Loss:99.55397507844042，此时此刻，我的K和B是-1.4919202248449164, 32.719249198231566
# 在第295步，我得到了一个更好的Loss:99.55128406152521，此时此刻，我的K和B是-1.4916654677907486, 32.717628658779816
# 在第296步，我得到了一个更好的Loss:99.54859317403145，此时此刻，我的K和B是-1.4914107168657176, 32.716008158297086
# 在第297步，我得到了一个更好的Loss:99.5459024159529，此时此刻，我的K和B是-1.4911559720694354, 32.714387696782474
# 在第298步，我得到了一个更好的Loss:99.54321178728333，此时此刻，我的K和B是-1.490901233401534, 32.71276727423508
# 在第299步，我得到了一个更好的Loss:99.5405212880165，此时此刻，我的K和B是-1.4906465008616627, 32.711146890653986
# 在第300步，我得到了一个更好的Loss:99.53783091814621，此时此刻，我的K和B是-1.4903917744494883, 32.7095265460383
# 在第301步，我得到了一个更好的Loss:99.53514067766623，此时此刻，我的K和B是-1.4901370541646923, 32.7079062403871
# 在第302步，我得到了一个更好的Loss:99.53245056657036，此时此刻，我的K和B是-1.4898823400069705, 32.706285973699494
# 在第303步，我得到了一个更好的Loss:99.52976058485234，此时此刻，我的K和B是-1.4896276319760315, 32.704665745974545
# 在第304步，我得到了一个更好的Loss:99.52707073250596，此时此刻，我的K和B是-1.4893729300715957, 32.70304555721135
# 在第305步，我得到了一个更好的Loss:99.524381009525，此时此刻，我的K和B是-1.4891182342933942, 32.70142540740898
# 在第306步，我得到了一个更好的Loss:99.52169141590323，此时此刻，我的K和B是-1.4888635446411684, 32.69980529656653
# 在第307步，我得到了一个更好的Loss:99.51900195163448，此时此刻，我的K和B是-1.4886088611146688, 32.69818522468307
# 在第308步，我得到了一个更好的Loss:99.51631261671245，此时此刻，我的K和B是-1.488354183713654, 32.696565191757685
# 在第309步，我得到了一个更好的Loss:99.51362341113095，此时此刻，我的K和B是-1.4880995124378904, 32.694945197789444
# 在第310步，我得到了一个更好的Loss:99.5109343348838，此时此刻，我的K和B是-1.4878448472871517, 32.693325242777426
# 在第311步，我得到了一个更好的Loss:99.50824538796472，此时此刻，我的K和B是-1.4875901882612177, 32.6917053267207
# 在第312步，我得到了一个更好的Loss:99.50555657036752，此时此刻，我的K和B是-1.4873355353598745, 32.69008544961835
# 在第313步，我得到了一个更好的Loss:99.50286788208598，此时此刻，我的K和B是-1.4870808885829134, 32.68846561146944
# 在第314步，我得到了一个更好的Loss:99.5001793231139，此时此刻，我的K和B是-1.486826247930131, 32.68684581227305
# 在第315步，我得到了一个更好的Loss:99.497490893445，此时此刻，我的K和B是-1.4865716134013287, 32.68522605202824
# 在第316步，我得到了一个更好的Loss:99.4948025930731，此时此刻，我的K和B是-1.4863169849963114, 32.683606330734094
# 在第317步，我得到了一个更好的Loss:99.492114421992，此时此刻，我的K和B是-1.4860623627148883, 32.681986648389675
# 在第318步，我得到了一个更好的Loss:99.48942638019547，此时此刻，我的K和B是-1.4858077465568726, 32.680367004994054
# 在第319步，我得到了一个更好的Loss:99.48673846767726，此时此刻，我的K和B是-1.4855531365220802, 32.6787474005463
# 在第320步，我得到了一个更好的Loss:99.4840506844312，此时此刻，我的K和B是-1.48529853261033, 32.677127835045475
# 在第321步，我得到了一个更好的Loss:99.481363030451，此时此刻，我的K和B是-1.485043934821444, 32.675508308490656
# 在第322步，我得到了一个更好的Loss:99.47867550573056，此时此刻，我的K和B是-1.4847893431552464, 32.67388882088091
# 在第323步，我得到了一个更好的Loss:99.47598811026356，此时此刻，我的K和B是-1.4845347576115642, 32.672269372215304
# 在第324步，我得到了一个更好的Loss:99.47330084404383，此时此刻，我的K和B是-1.484280178190226, 32.6706499624929
# 在第325步，我得到了一个更好的Loss:99.47061370706513，此时此刻，我的K和B是-1.4840256048910627, 32.669030591712776
# 在第326步，我得到了一个更好的Loss:99.46792669932125，此时此刻，我的K和B是-1.483771037713907, 32.66741125987399
# 在第327步，我得到了一个更好的Loss:99.46523982080598，此时此刻，我的K和B是-1.483516476658593, 32.665791966975604
# 在第328步，我得到了一个更好的Loss:99.46255307151314，此时此刻，我的K和B是-1.4832619217249567, 32.6641727130167
# 在第329步，我得到了一个更好的Loss:99.45986645143648，此时此刻，我的K和B是-1.4830073729128352, 32.66255349799633
# 在第330步，我得到了一个更好的Loss:99.45717996056976，此时此刻，我的K和B是-1.482752830222067, 32.660934321913565
# 在第331步，我得到了一个更好的Loss:99.45449359890684，此时此刻，我的K和B是-1.4824982936524917, 32.65931518476747
# 在第332步，我得到了一个更好的Loss:99.45180736644143，此时此刻，我的K和B是-1.4822437632039502, 32.65769608655712
# 在第333步，我得到了一个更好的Loss:99.44912126316736，此时此刻，我的K和B是-1.481989238876284, 32.65607702728156
# 在第334步，我得到了一个更好的Loss:99.44643528907837，此时此刻，我的K和B是-1.4817347206693359, 32.654458006939876
# 在第335步，我得到了一个更好的Loss:99.44374944416833，此时此刻，我的K和B是-1.4814802085829493, 32.65283902553112
# 在第336步，我得到了一个更好的Loss:99.44106372843095，此时此刻，我的K和B是-1.4812257026169684, 32.65122008305436
# 在第337步，我得到了一个更好的Loss:99.43837814186004，此时此刻，我的K和B是-1.4809712027712383, 32.649601179508664
# 在第338步，我得到了一个更好的Loss:99.43569268444942，此时此刻，我的K和B是-1.4807167090456046, 32.6479823148931
# 在第339步，我得到了一个更好的Loss:99.43300735619282，此时此刻，我的K和B是-1.4804622214399135, 32.64636348920672
# 在第340步，我得到了一个更好的Loss:99.43032215708408，此时此刻，我的K和B是-1.4802077399540114, 32.6447447024486
# 在第341步，我得到了一个更好的Loss:99.42763708711696，此时此刻，我的K和B是-1.479953264587746, 32.6431259546178
# 在第342步，我得到了一个更好的Loss:99.42495214628526，此时此刻，我的K和B是-1.4796987953409648, 32.64150724571339
# 在第343步，我得到了一个更好的Loss:99.42226733458278，此时此刻，我的K和B是-1.479444332213516, 32.63988857573443
# 在第344步，我得到了一个更好的Loss:99.41958265200329，此时此刻，我的K和B是-1.479189875205248, 32.63826994467999
# 在第345步，我得到了一个更好的Loss:99.41689809854057，此时此刻，我的K和B是-1.4789354243160098, 32.63665135254913
# 在第346步，我得到了一个更好的Loss:99.41421367418846，此时此刻，我的K和B是-1.4786809795456506, 32.63503279934091
# 在第347步，我得到了一个更好的Loss:99.41152937894068，此时此刻，我的K和B是-1.4784265408940198, 32.6334142850544
# 在第348步，我得到了一个更好的Loss:99.40884521279108，此时此刻，我的K和B是-1.4781721083609674, 32.63179580968866
# 在第349步，我得到了一个更好的Loss:99.40616117573343，此时此刻，我的K和B是-1.477917681946343, 32.630177373242766
# 在第350步，我得到了一个更好的Loss:99.40347726776152，此时此刻，我的K和B是-1.4776632616499974, 32.62855897571577
# 在第351步，我得到了一个更好的Loss:99.40079348886913，此时此刻，我的K和B是-1.4774088474717808, 32.62694061710674
# 在第352步，我得到了一个更好的Loss:99.39810983905008，此时此刻，我的K和B是-1.477154439411544, 32.62532229741475
# 在第353步，我得到了一个更好的Loss:99.39542631829814，此时此刻，我的K和B是-1.4769000374691377, 32.62370401663885
# 在第354步，我得到了一个更好的Loss:99.39274292660708，此时此刻，我的K和B是-1.4766456416444131, 32.62208577477811
# 在第355步，我得到了一个更好的Loss:99.39005966397077，此时此刻，我的K和B是-1.4763912519372215, 32.6204675718316
# 在第356步，我得到了一个更好的Loss:99.38737653038295，此时此刻，我的K和B是-1.476136868347414, 32.61884940779837
# 在第357步，我得到了一个更好的Loss:99.38469352583739，此时此刻，我的K和B是-1.4758824908748425, 32.6172312826775
# 在第358步，我得到了一个更好的Loss:99.38201065032793，此时此刻，我的K和B是-1.4756281195193581, 32.615613196468054
# 在第359步，我得到了一个更好的Loss:99.37932790384838，此时此刻，我的K和B是-1.4753737542808127, 32.613995149169085
# 在第360步，我得到了一个更好的Loss:99.37664528639246，此时此刻，我的K和B是-1.4751193951590582, 32.612377140779664
# 在第361步，我得到了一个更好的Loss:99.37396279795402，此时此刻，我的K和B是-1.4748650421539462, 32.61075917129886
# 在第362步，我得到了一个更好的Loss:99.37128043852685，此时此刻，我的K和B是-1.4746106952653288, 32.609141240725734
# 在第363步，我得到了一个更好的Loss:99.36859820810473，此时此刻，我的K和B是-1.4743563544930585, 32.60752334905935
# 在第364步，我得到了一个更好的Loss:99.36591610668147，此时此刻，我的K和B是-1.474102019836987, 32.60590549629877
# 在第365步，我得到了一个更好的Loss:99.36323413425086，此时此刻，我的K和B是-1.4738476912969665, 32.60428768244306
# 在第366步，我得到了一个更好的Loss:99.3605522908067，此时此刻，我的K和B是-1.4735933688728495, 32.60266990749128
# 在第367步，我得到了一个更好的Loss:99.35787057634276，此时此刻，我的K和B是-1.4733390525644883, 32.601052171442504
# 在第368步，我得到了一个更好的Loss:99.3551889908529，此时此刻，我的K和B是-1.473084742371735, 32.59943447429579
# 在第369步，我得到了一个更好的Loss:99.35250753433084，此时此刻，我的K和B是-1.4728304382944422, 32.597816816050205
# 在第370步，我得到了一个更好的Loss:99.34982620677042，此时此刻，我的K和B是-1.4725761403324622, 32.596199196704816
# 在第371步，我得到了一个更好的Loss:99.34714500816543，此时此刻，我的K和B是-1.472321848485648, 32.59458161625868
# 在第372步，我得到了一个更好的Loss:99.34446393850968，此时此刻，我的K和B是-1.4720675627538515, 32.59296407471087
# 在第373步，我得到了一个更好的Loss:99.34178299779694，此时此刻，我的K和B是-1.4718132831369257, 32.591346572060445
# 在第374步，我得到了一个更好的Loss:99.33910218602102，此时此刻，我的K和B是-1.4715590096347233, 32.58972910830647
# 在第375步，我得到了一个更好的Loss:99.33642150317573，此时此刻，我的K和B是-1.4713047422470966, 32.58811168344801
# 在第376步，我得到了一个更好的Loss:99.33374094925489，此时此刻，我的K和B是-1.4710504809738985, 32.58649429748414
# 在第377步，我得到了一个更好的Loss:99.33106052425225，此时此刻，我的K和B是-1.4707962258149816, 32.58487695041391
# 在第378步，我得到了一个更好的Loss:99.32838022816163，此时此刻，我的K和B是-1.4705419767701988, 32.58325964223639
# 在第379步，我得到了一个更好的Loss:99.32570006097686，此时此刻，我的K和B是-1.4702877338394027, 32.58164237295065
# 在第380步，我得到了一个更好的Loss:99.32302002269167，此时此刻，我的K和B是-1.4700334970224462, 32.58002514255574
# 在第381步，我得到了一个更好的Loss:99.32034011329993，此时此刻，我的K和B是-1.469779266319182, 32.57840795105074
# 在第382步，我得到了一个更好的Loss:99.31766033279544，此时此刻，我的K和B是-1.469525041729463, 32.576790798434715
# 在第383步，我得到了一个更好的Loss:99.31498068117195，此时此刻，我的K和B是-1.469270823253142, 32.57517368470672
# 在第384步，我得到了一个更好的Loss:99.3123011584233，此时此刻，我的K和B是-1.4690166108900717, 32.573556609865825
# 在第385步，我得到了一个更好的Loss:99.30962176454327，此时此刻，我的K和B是-1.468762404640105, 32.571939573911095
# 在第386步，我得到了一个更好的Loss:99.30694249952566，此时此刻，我的K和B是-1.468508204503095, 32.5703225768416
# 在第387步，我得到了一个更好的Loss:99.30426336336433，此时此刻，我的K和B是-1.4682540104788946, 32.568705618656395
# 在第388步，我得到了一个更好的Loss:99.301584356053，此时此刻，我的K和B是-1.4679998225673565, 32.56708869935455
# 在第389步，我得到了一个更好的Loss:99.29890547758552，此时此刻，我的K和B是-1.4677456407683336, 32.56547181893513
# 在第390步，我得到了一个更好的Loss:99.2962267279557，此时此刻，我的K和B是-1.4674914650816788, 32.5638549773972
# 在第391步，我得到了一个更好的Loss:99.29354810715729，此时此刻，我的K和B是-1.4672372955072452, 32.56223817473982
# 在第392步，我得到了一个更好的Loss:99.29086961518416，此时此刻，我的K和B是-1.4669831320448858, 32.56062141096206
# 在第393步，我得到了一个更好的Loss:99.28819125203009，此时此刻，我的K和B是-1.4667289746944534, 32.559004686062984
# 在第394步，我得到了一个更好的Loss:99.28551301768888，此时此刻，我的K和B是-1.466474823455801, 32.55738800004166
# 在第395步，我得到了一个更好的Loss:99.28283491215434，此时此刻，我的K和B是-1.4662206783287817, 32.55577135289715
# 在第396步，我得到了一个更好的Loss:99.28015693542028，此时此刻，我的K和B是-1.4659665393132484, 32.554154744628526
# 在第397步，我得到了一个更好的Loss:99.27747908748047，此时此刻，我的K和B是-1.465712406409054, 32.552538175234844
# 在第398步，我得到了一个更好的Loss:99.27480136832877，此时此刻，我的K和B是-1.4654582796160516, 32.55092164471517
# 在第399步，我得到了一个更好的Loss:99.27212377795892，此时此刻，我的K和B是-1.465204158934094, 32.549305153068566
# 在第400步，我得到了一个更好的Loss:99.26944631636479，此时此刻，我的K和B是-1.4649500443630346, 32.54768870029411
# 在第401步，我得到了一个更好的Loss:99.26676898354016，此时此刻，我的K和B是-1.464695935902726, 32.54607228639085
# 在第402步，我得到了一个更好的Loss:99.26409177947885，此时此刻，我的K和B是-1.4644418335530216, 32.54445591135787
# 在第403步，我得到了一个更好的Loss:99.26141470417464，此时此刻，我的K和B是-1.4641877373137742, 32.54283957519422
# 在第404步，我得到了一个更好的Loss:99.25873775762135，此时此刻，我的K和B是-1.4639336471848368, 32.54122327789898
# 在第405步，我得到了一个更好的Loss:99.25606093981278，此时此刻，我的K和B是-1.4636795631660624, 32.5396070194712
# 在第406步，我得到了一个更好的Loss:99.25338425074277，此时此刻，我的K和B是-1.463425485257304, 32.53799079990995
# 在第407步，我得到了一个更好的Loss:99.25070769040511，此时此刻，我的K和B是-1.463171413458415, 32.5363746192143
# 在第408步，我得到了一个更好的Loss:99.2480312587936，此时此刻，我的K和B是-1.4629173477692483, 32.53475847738331
# 在第409步，我得到了一个更好的Loss:99.24535495590206，此时此刻，我的K和B是-1.4626632881896569, 32.53314237441606
# 在第410步，我得到了一个更好的Loss:99.24267878172428，此时此刻，我的K和B是-1.4624092347194937, 32.5315263103116
# 在第411步，我得到了一个更好的Loss:99.24000273625411，此时此刻，我的K和B是-1.462155187358612, 32.52991028506899
# 在第412步，我得到了一个更好的Loss:99.23732681948532，此时此刻，我的K和B是-1.461901146106865, 32.528294298687314
# 在第413步，我得到了一个更好的Loss:99.23465103141174，此时此刻，我的K和B是-1.4616471109641056, 32.52667835116562
# 在第414步，我得到了一个更好的Loss:99.23197537202716，此时此刻，我的K和B是-1.4613930819301868, 32.525062442502986
# 在第415步，我得到了一个更好的Loss:99.22929984132543，此时此刻，我的K和B是-1.4611390590049618, 32.523446572698475
# 在第416步，我得到了一个更好的Loss:99.22662443930034，此时此刻，我的K和B是-1.4608850421882837, 32.52183074175115
# 在第417步，我得到了一个更好的Loss:99.22394916594568，此时此刻，我的K和B是-1.4606310314800057, 32.52021494966008
# 在第418步，我得到了一个更好的Loss:99.22127402125528，此时此刻，我的K和B是-1.4603770268799807, 32.518599196424326
# 在第419步，我得到了一个更好的Loss:99.21859900522297，此时此刻，我的K和B是-1.460123028388062, 32.51698348204295
# 在第420步，我得到了一个更好的Loss:99.21592411784253，此时此刻，我的K和B是-1.4598690360041024, 32.51536780651503
# 在第421步，我得到了一个更好的Loss:99.21324935910779，此时此刻，我的K和B是-1.4596150497279552, 32.51375216983963
# 在第422步，我得到了一个更好的Loss:99.21057472901258，此时此刻，我的K和B是-1.4593610695594736, 32.512136572015805
# 在第423步，我得到了一个更好的Loss:99.20790022755068，此时此刻，我的K和B是-1.4591070954985108, 32.51052101304263
# 在第424步，我得到了一个更好的Loss:99.2052258547159，此时此刻，我的K和B是-1.4588531275449197, 32.50890549291916
# 在第425步，我得到了一个更好的Loss:99.2025516105021，此时此刻，我的K和B是-1.4585991656985535, 32.50729001164447
# 在第426步，我得到了一个更好的Loss:99.19987749490303，此时此刻，我的K和B是-1.4583452099592653, 32.505674569217625
# 在第427步，我得到了一个更好的Loss:99.19720350791259，此时此刻，我的K和B是-1.4580912603269083, 32.50405916563769
# 在第428步，我得到了一个更好的Loss:99.19452964952453，此时此刻，我的K和B是-1.4578373168013357, 32.502443800903734
# 在第429步，我得到了一个更好的Loss:99.19185591973265，此时此刻，我的K和B是-1.4575833793824005, 32.50082847501481
# 在第430步，我得到了一个更好的Loss:99.18918231853081，此时此刻，我的K和B是-1.457329448069956, 32.49921318797001
# 在第431步，我得到了一个更好的Loss:99.1865088459128，此时此刻，我的K和B是-1.4570755228638552, 32.49759793976837
# 在第432步，我得到了一个更好的Loss:99.18383550187245，此时此刻，我的K和B是-1.4568216037639514, 32.49598273040897
# 在第433步，我得到了一个更好的Loss:99.18116228640359，此时此刻，我的K和B是-1.4565676907700977, 32.494367559890875
# 在第434步，我得到了一个更好的Loss:99.1784891995，此时此刻，我的K和B是-1.4563137838821472, 32.49275242821315
# 在第435步，我得到了一个更好的Loss:99.17581624115553，此时此刻，我的K和B是-1.4560598830999532, 32.491137335374866
# 在第436步，我得到了一个更好的Loss:99.173143411364，此时此刻，我的K和B是-1.4558059884233687, 32.48952228137509
# 在第437步，我得到了一个更好的Loss:99.17047071011916，此时此刻，我的K和B是-1.455552099852247, 32.48790726621287
# 在第438步，我得到了一个更好的Loss:99.16779813741492，此时此刻，我的K和B是-1.4552982173864413, 32.486292289887295
# 在第439步，我得到了一个更好的Loss:99.16512569324506，此时此刻，我的K和B是-1.4550443410258047, 32.48467735239742
# 在第440步，我得到了一个更好的Loss:99.16245337760338，此时此刻，我的K和B是-1.4547904707701904, 32.48306245374231
# 在第441步，我得到了一个更好的Loss:99.15978119048371，此时此刻，我的K和B是-1.4545366066194516, 32.48144759392104
# 在第442步，我得到了一个更好的Loss:99.15710913187986，此时此刻，我的K和B是-1.4542827485734415, 32.47983277293267
# 在第443步，我得到了一个更好的Loss:99.15443720178568，此时此刻，我的K和B是-1.4540288966320134, 32.47821799077626
# 在第444步，我得到了一个更好的Loss:99.15176540019496，此时此刻，我的K和B是-1.4537750507950205, 32.47660324745088
# 在第445步，我得到了一个更好的Loss:99.14909372710153，此时此刻，我的K和B是-1.453521211062316, 32.4749885429556
# 在第446步，我得到了一个更好的Loss:99.14642218249925，此时此刻，我的K和B是-1.4532673774337528, 32.47337387728948
# 在第447步，我得到了一个更好的Loss:99.14375076638184，此时此刻，我的K和B是-1.4530135499091843, 32.4717592504516
# 在第448步，我得到了一个更好的Loss:99.14107947874321，此时此刻，我的K和B是-1.452759728488464, 32.47014466244101
# 在第449步，我得到了一个更好的Loss:99.13840831957714，此时此刻，我的K和B是-1.4525059131714446, 32.46853011325678
# 在第450步，我得到了一个更好的Loss:99.13573728887748，此时此刻，我的K和B是-1.4522521039579797, 32.46691560289799
# 在第451步，我得到了一个更好的Loss:99.13306638663805，此时此刻，我的K和B是-1.4519983008479223, 32.465301131363695
# 在第452步，我得到了一个更好的Loss:99.13039561285261，此时此刻，我的K和B是-1.4517445038411259, 32.46368669865296
# 在第453步，我得到了一个更好的Loss:99.12772496751505，此时此刻，我的K和B是-1.4514907129374435, 32.46207230476485
# 在第454步，我得到了一个更好的Loss:99.12505445061919，此时此刻，我的K和B是-1.4512369281367283, 32.460457949698444
# 在第455步，我得到了一个更好的Loss:99.12238406215882，此时此刻，我的K和B是-1.4509831494388339, 32.458843633452794
# 在第456步，我得到了一个更好的Loss:99.11971380212778，此时此刻，我的K和B是-1.4507293768436131, 32.45722935602697
# 在第457步，我得到了一个更好的Loss:99.11704367051989，此时此刻，我的K和B是-1.4504756103509193, 32.455615117420045
# 在第458步，我得到了一个更好的Loss:99.11437366732896，此时此刻，我的K和B是-1.4502218499606059, 32.45400091763108
# 在第459步，我得到了一个更好的Loss:99.11170379254885，此时此刻，我的K和B是-1.449968095672526, 32.45238675665914
# 在第460步，我得到了一个更好的Loss:99.10903404617333，此时此刻，我的K和B是-1.449714347486533, 32.450772634503295
# 在第461步，我得到了一个更好的Loss:99.1063644281963，此时此刻，我的K和B是-1.4494606054024801, 32.44915855116261
# 在第462步，我得到了一个更好的Loss:99.10369493861153，此时此刻，我的K和B是-1.4492068694202205, 32.447544506636156
# 在第463步，我得到了一个更好的Loss:99.10102557741284，此时此刻，我的K和B是-1.4489531395396074, 32.445930500923
# 在第464步，我得到了一个更好的Loss:99.0983563445941，此时此刻，我的K和B是-1.4486994157604942, 32.4443165340222
# 在第465步，我得到了一个更好的Loss:99.09568724014906，此时此刻，我的K和B是-1.4484456980827343, 32.44270260593282
# 在第466步，我得到了一个更好的Loss:99.09301826407163，此时此刻，我的K和B是-1.4481919865061808, 32.441088716653944
# 在第467步，我得到了一个更好的Loss:99.0903494163556，此时此刻，我的K和B是-1.447938281030687, 32.439474866184625
# 在第468步，我得到了一个更好的Loss:99.0876806969948，此时此刻，我的K和B是-1.447684581656106, 32.437861054523935
# 在第469步，我得到了一个更好的Loss:99.08501210598303，此时此刻，我的K和B是-1.4474308883822913, 32.43624728167094
# 在第470步，我得到了一个更好的Loss:99.08234364331415，此时此刻，我的K和B是-1.4471772012090962, 32.4346335476247
# 在第471步，我得到了一个更好的Loss:99.07967530898198，此时此刻，我的K和B是-1.446923520136374, 32.43301985238429
# 在第472步，我得到了一个更好的Loss:99.07700710298035，此时此刻，我的K和B是-1.446669845163978, 32.431406195948774
# 在第473步，我得到了一个更好的Loss:99.07433902530309，此时此刻，我的K和B是-1.4464161762917613, 32.429792578317226
# 在第474步，我得到了一个更好的Loss:99.07167107594401，此时此刻，我的K和B是-1.4461625135195777, 32.4281789994887
# 在第475步，我得到了一个更好的Loss:99.06900325489696，此时此刻，我的K和B是-1.44590885684728, 32.426565459462275
# 在第476步，我得到了一个更好的Loss:99.06633556215576，此时此刻，我的K和B是-1.4456552062747219, 32.42495195823701
# 在第477步，我得到了一个更好的Loss:99.06366799771423，此时此刻，我的K和B是-1.4454015618017564, 32.423338495811976
# 在第478步，我得到了一个更好的Loss:99.06100056156622，此时此刻，我的K和B是-1.445147923428237, 32.421725072186234
# 在第479步，我得到了一个更好的Loss:99.05833325370556，此时此刻，我的K和B是-1.444894291154017, 32.420111687358855
# 在第480步，我得到了一个更好的Loss:99.05566607412605，此时此刻，我的K和B是-1.4446406649789496, 32.418498341328906
# 在第481步，我得到了一个更好的Loss:99.05299902282155，此时此刻，我的K和B是-1.4443870449028884, 32.41688503409546
# 在第482步，我得到了一个更好的Loss:99.05033209978586，此时此刻，我的K和B是-1.4441334309256864, 32.41527176565757
# 在第483步，我得到了一个更好的Loss:99.04766530501286，此时此刻，我的K和B是-1.4438798230471972, 32.41365853601432
# 在第484步，我得到了一个更好的Loss:99.04499863849634，此时此刻，我的K和B是-1.4436262212672741, 32.41204534516476
# 在第485步，我得到了一个更好的Loss:99.04233210023014，此时此刻，我的K和B是-1.4433726255857704, 32.41043219310797
# 在第486步，我得到了一个更好的Loss:99.03966569020811，此时此刻，我的K和B是-1.4431190360025394, 32.40881907984301
# 在第487步，我得到了一个更好的Loss:99.03699940842405，此时此刻，我的K和B是-1.4428654525174345, 32.407206005368955
# 在第488步，我得到了一个更好的Loss:99.03433325487184，此时此刻，我的K和B是-1.442611875130309, 32.40559296968487
# 在第489步，我得到了一个更好的Loss:99.03166722954526，此时此刻，我的K和B是-1.4423583038410164, 32.40397997278981
# 在第490步，我得到了一个更好的Loss:99.02900133243818，此时此刻，我的K和B是-1.4421047386494101, 32.40236701468286
# 在第491步，我得到了一个更好的Loss:99.02633556354442，此时此刻，我的K和B是-1.4418511795553435, 32.40075409536307
# 在第492步，我得到了一个更好的Loss:99.0236699228578，此时此刻，我的K和B是-1.4415976265586696, 32.39914121482952
# 在第493步，我得到了一个更好的Loss:99.02100441037219，此时此刻，我的K和B是-1.441344079659242, 32.39752837308127
# 在第494步，我得到了一个更好的Loss:99.01833902608139，此时此刻，我的K和B是-1.4410905388569142, 32.395915570117396
# 在第495步，我得到了一个更好的Loss:99.01567376997924，此时此刻，我的K和B是-1.4408370041515393, 32.39430280593696
# 在第496步，我得到了一个更好的Loss:99.0130086420596，此时此刻，我的K和B是-1.440583475542971, 32.392690080539026
# 在第497步，我得到了一个更好的Loss:99.01034364231627，此时此刻，我的K和B是-1.4403299530310625, 32.391077393922664
# 在第498步，我得到了一个更好的Loss:99.00767877074311，此时此刻，我的K和B是-1.440076436615667, 32.389464746086944
# 在第499步，我得到了一个更好的Loss:99.00501402733396，此时此刻，我的K和B是-1.4398229262966384, 32.38785213703093
# 在第500步，我得到了一个更好的Loss:99.00234941208262，此时此刻，我的K和B是-1.4395694220738298, 32.386239566753694
# 在第501步，我得到了一个更好的Loss:98.99968492498297，此时此刻，我的K和B是-1.4393159239470945, 32.3846270352543
# 在第502步，我得到了一个更好的Loss:98.99702056602882，此时此刻，我的K和B是-1.4390624319162861, 32.38301454253181
# 在第503步，我得到了一个更好的Loss:98.99435633521402，此时此刻，我的K和B是-1.438808945981258, 32.381402088585304
# 在第504步，我得到了一个更好的Loss:98.9916922325324，此时此刻，我的K和B是-1.4385554661418636, 32.37978967341384
# 在第505步，我得到了一个更好的Loss:98.98902825797782，此时此刻，我的K和B是-1.438301992397956, 32.37817729701649
# 在第506步，我得到了一个更好的Loss:98.98636441154409，此时此刻，我的K和B是-1.4380485247493893, 32.376564959392326
# 在第507步，我得到了一个更好的Loss:98.98370069322503，此时此刻，我的K和B是-1.4377950631960164, 32.3749526605404
# 在第508步，我得到了一个更好的Loss:98.98103710301453，此时此刻，我的K和B是-1.4375416077376908, 32.373340400459796
# 在第509步，我得到了一个更好的Loss:98.9783736409064，此时此刻，我的K和B是-1.437288158374266, 32.37172817914957
# 在第510步，我得到了一个更好的Loss:98.97571030689447，此时此刻，我的K和B是-1.4370347151055953, 32.370115996608796
# 在第511步，我得到了一个更好的Loss:98.9730471009726，此时此刻，我的K和B是-1.4367812779315323, 32.36850385283654
# 在第512步，我得到了一个更好的Loss:98.9703840231346，此时此刻，我的K和B是-1.4365278468519305, 32.36689174783187
# 在第513步，我得到了一个更好的Loss:98.96772107337435，此时此刻，我的K和B是-1.436274421866643, 32.365279681593854
# 在第514步，我得到了一个更好的Loss:98.96505825168568，此时此刻，我的K和B是-1.4360210029755236, 32.36366765412156
# 在第515步，我得到了一个更好的Loss:98.9623955580624，此时此刻，我的K和B是-1.4357675901784257, 32.36205566541406
# 在第516步，我得到了一个更好的Loss:98.9597329924984，此时此刻，我的K和B是-1.4355141834752025, 32.36044371547042
# 在第517步，我得到了一个更好的Loss:98.9570705549875，此时此刻，我的K和B是-1.4352607828657078, 32.3588318042897
# 在第518步，我得到了一个更好的Loss:98.9544082455235，此时此刻，我的K和B是-1.435007388349795, 32.35721993187097
# 在第519步，我得到了一个更好的Loss:98.95174606410029，此时此刻，我的K和B是-1.4347539999273173, 32.3556080982133
# 在第520步，我得到了一个更好的Loss:98.94908401071169，此时此刻，我的K和B是-1.4345006175981285, 32.35399630331577
# 在第521步，我得到了一个更好的Loss:98.94642208535159，此时此刻，我的K和B是-1.434247241362082, 32.35238454717743
# 在第522步，我得到了一个更好的Loss:98.94376028801375，此时此刻，我的K和B是-1.433993871219031, 32.35077282979735
# 在第523步，我得到了一个更好的Loss:98.94109861869208，此时此刻，我的K和B是-1.4337405071688294, 32.349161151174606
# 在第524步，我得到了一个更好的Loss:98.93843707738039，此时此刻，我的K和B是-1.4334871492113304, 32.347549511308266
# 在第525步，我得到了一个更好的Loss:98.93577566407252，此时此刻，我的K和B是-1.4332337973463876, 32.34593791019739
# 在第526步，我得到了一个更好的Loss:98.93311437876237，此时此刻，我的K和B是-1.4329804515738542, 32.344326347841054
# 在第527步，我得到了一个更好的Loss:98.9304532214437，此时此刻，我的K和B是-1.4327271118935843, 32.34271482423832
# 在第528步，我得到了一个更好的Loss:98.92779219211043，此时此刻，我的K和B是-1.4324737783054309, 32.34110333938826
# 在第529步，我得到了一个更好的Loss:98.92513129075635，此时此刻，我的K和B是-1.4322204508092475, 32.339491893289946
# 在第530步，我得到了一个更好的Loss:98.92247051737532，此时此刻，我的K和B是-1.431967129404888, 32.337880485942435
# 在第531步，我得到了一个更好的Loss:98.91980987196119，此时此刻，我的K和B是-1.4317138140922054, 32.336269117344806
# 在第532步，我得到了一个更好的Loss:98.91714935450784，此时此刻，我的K和B是-1.4314605048710536, 32.33465778749612
# 在第533步，我得到了一个更好的Loss:98.91448896500906，此时此刻，我的K和B是-1.431207201741286, 32.33304649639545
# 在第534步，我得到了一个更好的Loss:98.91182870345872，此时此刻，我的K和B是-1.4309539047027562, 32.331435244041856
# 在第535步，我得到了一个更好的Loss:98.90916856985065，此时此刻，我的K和B是-1.4307006137553175, 32.329824030434416
# 在第536步，我得到了一个更好的Loss:98.90650856417874，此时此刻，我的K和B是-1.4304473288988235, 32.32821285557219
# 在第537步，我得到了一个更好的Loss:98.90384868643677，此时此刻，我的K和B是-1.4301940501331278, 32.32660171945425
# 在第538步，我得到了一个更好的Loss:98.90118893661865，此时此刻，我的K和B是-1.429940777458084, 32.32499062207967
# 在第539步，我得到了一个更好的Loss:98.89852931471822，此时此刻，我的K和B是-1.4296875108735454, 32.32337956344751
# ...
# 在第821步，我得到了一个更好的Loss:98.15359707673969，此时此刻，我的K和B是-1.3585088111524497, 31.870603454746053
# 在第822步，我得到了一个更好的Loss:98.15097340942829，此时此刻，我的K和B是-1.3582572623085738, 31.86900332286496
# 在第823步，我得到了一个更好的Loss:98.1483498682992，此时此刻，我的K和B是-1.3580057195137498, 31.8674032294626
# 在第824步，我得到了一个更好的Loss:98.14572645334638，此时此刻，我的K和B是-1.3577541827678326, 31.865803174538048
# 在第825步，我得到了一个更好的Loss:98.14310316456375，此时此刻，我的K和B是-1.3575026520706763, 31.86420315809038
# 在第826步，我得到了一个更好的Loss:98.14048000194525，此时此刻，我的K和B是-1.3572511274221357, 31.86260318011867
# 在第827步，我得到了一个更好的Loss:98.13785696548477，此时此刻，我的K和B是-1.356999608822065, 31.86100324062199
# 在第828步，我得到了一个更好的Loss:98.13523405517633，此时此刻，我的K和B是-1.3567480962703191, 31.85940333959942
# 在第829步，我得到了一个更好的Loss:98.13261127101376，此时此刻，我的K和B是-1.3564965897667525, 31.857803477050034
# 在第830步，我得到了一个更好的Loss:98.12998861299106，此时此刻，我的K和B是-1.3562450893112197, 31.8562036529729
# 在第831步，我得到了一个更好的Loss:98.12736608110215，此时此刻，我的K和B是-1.3559935949035753, 31.8546038673671
# 在第832步，我得到了一个更好的Loss:98.12474367534095，此时此刻，我的K和B是-1.3557421065436739, 31.853004120231706
# 在第833步，我得到了一个更好的Loss:98.12212139570141，此时此刻，我的K和B是-1.35549062423137, 31.851404411565795
# 在第834步，我得到了一个更好的Loss:98.11949924217745，此时此刻，我的K和B是-1.3552391479665182, 31.84980474136844
# 在第835步，我得到了一个更好的Loss:98.11687721476305，此时此刻，我的K和B是-1.354987677748973, 31.848205109638716
# 在第836步，我得到了一个更好的Loss:98.11425531345206，此时此刻，我的K和B是-1.3547362135785892, 31.8466055163757
# 在第837步，我得到了一个更好的Loss:98.11163353823848，此时此刻，我的K和B是-1.3544847554552213, 31.84500596157846
# 在第838步，我得到了一个更好的Loss:98.10901188911623，此时此刻，我的K和B是-1.3542333033787237, 31.84340644524608
# 在第839步，我得到了一个更好的Loss:98.10639036607925，此时此刻，我的K和B是-1.353981857348951, 31.841806967377632
# 在第840步，我得到了一个更好的Loss:98.10376896912146，此时此刻，我的K和B是-1.353730417365758, 31.84020752797219
# 在第841步，我得到了一个更好的Loss:98.1011476982368，此时此刻，我的K和B是-1.3534789834289993, 31.838608127028827
# 在第842步，我得到了一个更好的Loss:98.09852655341922，此时此刻，我的K和B是-1.3532275555385294, 31.837008764546624
# 在第843步，我得到了一个更好的Loss:98.09590553466263，此时此刻，我的K和B是-1.3529761336942028, 31.83540944052465
# 在第844步，我得到了一个更好的Loss:98.09328464196103，此时此刻，我的K和B是-1.3527247178958741, 31.833810154961984
# 在第845步，我得到了一个更好的Loss:98.09066387530828，此时此刻，我的K和B是-1.3524733081433982, 31.8322109078577
# 在第846步，我得到了一个更好的Loss:98.08804323469836，此时此刻，我的K和B是-1.3522219044366293, 31.830611699210873
# 在第847步，我得到了一个更好的Loss:98.0854227201252，此时此刻，我的K和B是-1.3519705067754222, 31.829012529020577
# 在第848步，我得到了一个更好的Loss:98.08280233158277，此时此刻，我的K和B是-1.3517191151596317, 31.82741339728589
# 在第849步，我得到了一个更好的Loss:98.08018206906495，此时此刻，我的K和B是-1.3514677295891122, 31.82581430400589
# 在第850步，我得到了一个更好的Loss:98.0775619325657，此时此刻，我的K和B是-1.3512163500637187, 31.82421524917964
# 在第851步，我得到了一个更好的Loss:98.07494192207898，此时此刻，我的K和B是-1.3509649765833054, 31.82261623280623
# 在第852步，我得到了一个更好的Loss:98.0723220375987，此时此刻，我的K和B是-1.350713609147727, 31.821017254884726
# 在第853步，我得到了一个更好的Loss:98.06970227911881，此时此刻，我的K和B是-1.3504622477568382, 31.819418315414207
# 在第854步，我得到了一个更好的Loss:98.06708264663328，此时此刻，我的K和B是-1.3502108924104939, 31.817819414393746
# 在第855步，我得到了一个更好的Loss:98.06446314013601，此时此刻，我的K和B是-1.3499595431085483, 31.81622055182242
# 在第856步，我得到了一个更好的Loss:98.06184375962096，此时此刻，我的K和B是-1.3497081998508562, 31.8146217276993
# 在第857步，我得到了一个更好的Loss:98.05922450508206，此时此刻，我的K和B是-1.3494568626372725, 31.81302294202347
# 在第858步，我得到了一个更好的Loss:98.05660537651328，此时此刻，我的K和B是-1.3492055314676517, 31.811424194794
# 在第859步，我得到了一个更好的Loss:98.05398637390851，此时此刻，我的K和B是-1.3489542063418483, 31.809825486009967
# 在第860步，我得到了一个更好的Loss:98.05136749726175，此时此刻，我的K和B是-1.348702887259717, 31.808226815670444
# 在第861步，我得到了一个更好的Loss:98.0487487465669，此时此刻，我的K和B是-1.3484515742211127, 31.80662818377451
# 在第862步，我得到了一个更好的Loss:98.04613012181794，此时此刻，我的K和B是-1.34820026722589, 31.80502959032124
# 在第863步，我得到了一个更好的Loss:98.04351162300877，此时此刻，我的K和B是-1.3479489662739033, 31.803431035309707
# 在第864步，我得到了一个更好的Loss:98.04089325013335，此时此刻，我的K和B是-1.3476976713650075, 31.80183251873899
# 在第865步，我得到了一个更好的Loss:98.03827500318565，此时此刻，我的K和B是-1.3474463824990572, 31.800234040608164
# 在第866步，我得到了一个更好的Loss:98.03565688215957，此时此刻，我的K和B是-1.3471950996759072, 31.798635600916302
# 在第867步，我得到了一个更好的Loss:98.03303888704906，此时此刻，我的K和B是-1.3469438228954123, 31.79703719966248
# 在第868步，我得到了一个更好的Loss:98.03042101784811，此时此刻，我的K和B是-1.346692552157427, 31.795438836845776
# 在第869步，我得到了一个更好的Loss:98.0278032745506，此时此刻，我的K和B是-1.3464412874618057, 31.793840512465263
# 在第870步，我得到了一个更好的Loss:98.02518565715054，此时此刻，我的K和B是-1.3461900288084037, 31.79224222652002
# 在第871步，我得到了一个更好的Loss:98.02256816564184，此时此刻，我的K和B是-1.3459387761970754, 31.790643979009122
# 在第872步，我得到了一个更好的Loss:98.01995080001844，此时此刻，我的K和B是-1.3456875296276753, 31.78904576993164
# 在第873步，我得到了一个更好的Loss:98.01733356027427，此时此刻，我的K和B是-1.3454362891000584, 31.787447599286654
# 在第874步，我得到了一个更好的Loss:98.01471644640331，此时此刻，我的K和B是-1.3451850546140793, 31.78584946707324
# 在第875步，我得到了一个更好的Loss:98.01209945839952，此时此刻，我的K和B是-1.344933826169593, 31.784251373290473
# 在第876步，我得到了一个更好的Loss:98.00948259625679，此时此刻，我的K和B是-1.3446826037664537, 31.78265331793743
# 在第877步，我得到了一个更好的Loss:98.00686585996912，此时此刻，我的K和B是-1.3444313874045164, 31.781055301013186
# 在第878步，我得到了一个更好的Loss:98.00424924953043，此时此刻，我的K和B是-1.344180177083636, 31.779457322516816
# 在第879步，我得到了一个更好的Loss:98.00163276493467，此时此刻，我的K和B是-1.343928972803667, 31.777859382447396
# 在第880步，我得到了一个更好的Loss:97.9990164061758，此时此刻，我的K和B是-1.3436777745644641, 31.776261480804003
# 在第881步，我得到了一个更好的Loss:97.99640017324776，此时此刻，我的K和B是-1.3434265823658822, 31.774663617585713
# 在第882步，我得到了一个更好的Loss:97.99378406614449，此时此刻，我的K和B是-1.343175396207776, 31.773065792791602
# 在第883步，我得到了一个更好的Loss:97.99116808485995，此时此刻，我的K和B是-1.3429242160900001, 31.771468006420744
# 在第884步，我得到了一个更好的Loss:97.98855222938809，此时此刻，我的K和B是-1.3426730420124096, 31.769870258472217
# 在第885步，我得到了一个更好的Loss:97.98593649972285，此时此刻，我的K和B是-1.3424218739748588, 31.768272548945095
# 在第886步，我得到了一个更好的Loss:97.98332089585817，此时此刻，我的K和B是-1.3421707119772026, 31.766674877838458
# 在第887步，我得到了一个更好的Loss:97.98070541778806，此时此刻，我的K和B是-1.3419195560192958, 31.765077245151378
# 在第888步，我得到了一个更好的Loss:97.97809006550638，此时此刻，我的K和B是-1.3416684061009931, 31.763479650882935
# 在第889步，我得到了一个更好的Loss:97.97547483900713，此时此刻，我的K和B是-1.3414172622221496, 31.761882095032202
# 在第890步，我得到了一个更好的Loss:97.97285973828427，此时此刻，我的K和B是-1.3411661243826196, 31.760284577598256
# 在第891步，我得到了一个更好的Loss:97.97024476333172，此时此刻，我的K和B是-1.340914992582258, 31.75868709858017
# 在第892步，我得到了一个更好的Loss:97.96762991414346，此时此刻，我的K和B是-1.3406638668209199, 31.75708965797703
# 在第893步，我得到了一个更好的Loss:97.96501519071343，此时此刻，我的K和B是-1.3404127470984597, 31.755492255787903
# 在第894步，我得到了一个更好的Loss:97.96240059303558，此时此刻，我的K和B是-1.3401616334147324, 31.753894892011868
# 在第895步，我得到了一个更好的Loss:97.95978612110385，此时此刻，我的K和B是-1.3399105257695927, 31.752297566648
# 在第896步，我得到了一个更好的Loss:97.95717177491221，此时此刻，我的K和B是-1.3396594241628952, 31.750700279695376
# 在第897步，我得到了一个更好的Loss:97.95455755445461，此时此刻，我的K和B是-1.3394083285944949, 31.749103031153076
# 在第898步，我得到了一个更好的Loss:97.951943459725，此时此刻，我的K和B是-1.3391572390642466, 31.747505821020173
# 在第899步，我得到了一个更好的Loss:97.94932949071735，此时此刻，我的K和B是-1.338906155572005, 31.745908649295743
# 在第900步，我得到了一个更好的Loss:97.94671564742556，此时此刻，我的K和B是-1.3386550781176252, 31.74431151597886
# 在第901步，我得到了一个更好的Loss:97.94410192984367，此时此刻，我的K和B是-1.3384040067009617, 31.74271442106861
# 在第902步，我得到了一个更好的Loss:97.94148833796552，此时此刻，我的K和B是-1.3381529413218693, 31.741117364564058
# 在第903步，我得到了一个更好的Loss:97.93887487178519，此时此刻，我的K和B是-1.337901881980203, 31.739520346464285
# 在第904步，我得到了一个更好的Loss:97.93626153129655，此时此刻，我的K和B是-1.3376508286758175, 31.73792336676837
# 在第905步，我得到了一个更好的Loss:97.93364831649357，此时此刻，我的K和B是-1.3373997814085676, 31.736326425475387
# 在第906步，我得到了一个更好的Loss:97.93103522737023，此时此刻，我的K和B是-1.3371487401783082, 31.734729522584413
# 在第907步，我得到了一个更好的Loss:97.92842226392047，此时此刻，我的K和B是-1.3368977049848942, 31.733132658094522
# 在第908步，我得到了一个更好的Loss:97.92580942613826，此时此刻，我的K和B是-1.3366466758281803, 31.731535832004795
# 在第909步，我得到了一个更好的Loss:97.92319671401751，此时此刻，我的K和B是-1.3363956527080214, 31.729939044314307
# 在第910步，我得到了一个更好的Loss:97.92058412755222，此时此刻，我的K和B是-1.336144635624272, 31.72834229502213
# 在第911步，我得到了一个更好的Loss:97.91797166673634，此时此刻，我的K和B是-1.3358936245767876, 31.726745584127347
# 在第912步，我得到了一个更好的Loss:97.91535933156382，此时此刻，我的K和B是-1.3356426195654225, 31.72514891162903
# 在第913步，我得到了一个更好的Loss:97.91274712202862，此时此刻，我的K和B是-1.3353916205900318, 31.72355227752626
# 在第914步，我得到了一个更好的Loss:97.91013503812468，此时此刻，我的K和B是-1.33514062765047, 31.721955681818113
# 在第915步，我得到了一个更好的Loss:97.907523079846，此时此刻，我的K和B是-1.3348896407465924, 31.720359124503663
# 在第916步，我得到了一个更好的Loss:97.9049112471865，此时此刻，我的K和B是-1.3346386598782538, 31.71876260558199
# 在第917步，我得到了一个更好的Loss:97.90229954014016，此时此刻，我的K和B是-1.334387685045309, 31.717166125052167
# 在第918步，我得到了一个更好的Loss:97.89968795870092，此时此刻，我的K和B是-1.3341367162476125, 31.715569682913273
# 在第919步，我得到了一个更好的Loss:97.89707650286277，此时此刻，我的K和B是-1.3338857534850197, 31.713973279164385
# 在第920步，我得到了一个更好的Loss:97.89446517261965，此时此刻，我的K和B是-1.3336347967573852, 31.71237691380458
# 在第921步，我得到了一个更好的Loss:97.8918539679655，此时此刻，我的K和B是-1.333383846064564, 31.710780586832932
# 在第922步，我得到了一个更好的Loss:97.8892428888943，此时此刻，我的K和B是-1.3331329014064108, 31.70918429824852
# 在第923步，我得到了一个更好的Loss:97.88663193540002，此时此刻，我的K和B是-1.3328819627827806, 31.70758804805042
# 在第924步，我得到了一个更好的Loss:97.8840211074766，此时此刻，我的K和B是-1.3326310301935282, 31.705991836237715
# 在第925步，我得到了一个更好的Loss:97.88141040511802，此时此刻，我的K和B是-1.3323801036385088, 31.704395662809475
# 在第926步，我得到了一个更好的Loss:97.87879982831824，此时此刻，我的K和B是-1.332129183117577, 31.70279952776478
# 在第927步，我得到了一个更好的Loss:97.8761893770712，此时此刻，我的K和B是-1.3318782686305877, 31.7012034311027
# 在第928步，我得到了一个更好的Loss:97.87357905137087，此时此刻，我的K和B是-1.3316273601773958, 31.69960737282232
# 在第929步，我得到了一个更好的Loss:97.8709688512112，此时此刻，我的K和B是-1.3313764577578564, 31.698011352922716
# 在第930步，我得到了一个更好的Loss:97.86835877658619，此时此刻，我的K和B是-1.3311255613718243, 31.696415371402964
# 在第931步，我得到了一个更好的Loss:97.8657488274898，此时此刻，我的K和B是-1.3308746710191544, 31.69481942826214
# 在第932步，我得到了一个更好的Loss:97.86313900391593，此时此刻，我的K和B是-1.3306237866997015, 31.69322352349932
# 在第933步，我得到了一个更好的Loss:97.86052930585862，此时此刻，我的K和B是-1.3303729084133207, 31.691627657113585
# 在第934步，我得到了一个更好的Loss:97.85791973331179，此时此刻，我的K和B是-1.3301220361598667, 31.69003182910401
# 在第935步，我得到了一个更好的Loss:97.85531028626941，此时此刻，我的K和B是-1.3298711699391947, 31.688436039469675
# 在第936步，我得到了一个更好的Loss:97.85270096472547，此时此刻，我的K和B是-1.3296203097511594, 31.686840288209652
# 在第937步，我得到了一个更好的Loss:97.85009176867389，此时此刻，我的K和B是-1.329369455595616, 31.685244575323022
# 在第938步，我得到了一个更好的Loss:97.84748269810868，此时此刻，我的K和B是-1.329118607472419, 31.68364890080886
# 在第939步，我得到了一个更好的Loss:97.84487375302375，此时此刻，我的K和B是-1.3288677653814238, 31.682053264666244
# 在第940步，我得到了一个更好的Loss:97.84226493341312，此时此刻，我的K和B是-1.3286169293224852, 31.680457666894252
# 在第941步，我得到了一个更好的Loss:97.83965623927074，此时此刻，我的K和B是-1.328366099295458, 31.678862107491963
# 在第942步，我得到了一个更好的Loss:97.83704767059056，此时此刻，我的K和B是-1.3281152753001972, 31.677266586458448
# 在第943步，我得到了一个更好的Loss:97.83443922736653，此时此刻，我的K和B是-1.327864457336558, 31.67567110379279
# 在第944步，我得到了一个更好的Loss:97.83183090959267，此时此刻，我的K和B是-1.3276136454043947, 31.674075659494065
# 在第945步，我得到了一个更好的Loss:97.82922271726291，此时此刻，我的K和B是-1.327362839503563, 31.67248025356135
# 在第946步，我得到了一个更好的Loss:97.82661465037123，此时此刻，我的K和B是-1.3271120396339176, 31.670884885993722
# 在第947步，我得到了一个更好的Loss:97.82400670891158，此时此刻，我的K和B是-1.3268612457953133, 31.66928955679026
# 在第948步，我得到了一个更好的Loss:97.82139889287794，此时此刻，我的K和B是-1.3266104579876052, 31.66769426595004
# 在第949步，我得到了一个更好的Loss:97.8187912022643，此时此刻，我的K和B是-1.3263596762106484, 31.666099013472138
# 在第950步，我得到了一个更好的Loss:97.81618363706457，此时此刻，我的K和B是-1.3261089004642976, 31.664503799355636
# 在第951步，我得到了一个更好的Loss:97.81357619727275，此时此刻，我的K和B是-1.325858130748408, 31.66290862359961
# 在第952步，我得到了一个更好的Loss:97.81096888288285，此时此刻，我的K和B是-1.3256073670628346, 31.661313486203134
# 在第953步，我得到了一个更好的Loss:97.80836169388878，此时此刻，我的K和B是-1.3253566094074323, 31.659718387165288
# 在第954步，我得到了一个更好的Loss:97.80575463028451，此时此刻，我的K和B是-1.325105857782056, 31.65812332648515
# 在第955步，我得到了一个更好的Loss:97.80314769206406，此时此刻，我的K和B是-1.3248551121865608, 31.656528304161796
# 在第956步，我得到了一个更好的Loss:97.80054087922136，此时此刻，我的K和B是-1.3246043726208017, 31.654933320194306
# 在第957步，我得到了一个更好的Loss:97.7979341917504，此时此刻，我的K和B是-1.3243536390846335, 31.653338374581757
# 在第958步，我得到了一个更好的Loss:97.79532762964512，此时此刻，我的K和B是-1.3241029115779117, 31.651743467323225
# 在第959步，我得到了一个更好的Loss:97.79272119289952，此时此刻，我的K和B是-1.323852190100491, 31.65014859841779
# 在第960步，我得到了一个更好的Loss:97.79011488150755，此时此刻，我的K和B是-1.3236014746522262, 31.648553767864527
# 在第961步，我得到了一个更好的Loss:97.78750869546322，此时此刻，我的K和B是-1.3233507652329726, 31.646958975662518
# 在第962步，我得到了一个更好的Loss:97.78490263476046，此时此刻，我的K和B是-1.3231000618425852, 31.645364221810837
# 在第963步，我得到了一个更好的Loss:97.78229669939326，此时此刻，我的K和B是-1.322849364480919, 31.643769506308562
# 在第964步，我得到了一个更好的Loss:97.77969088935558，此时此刻，我的K和B是-1.322598673147829, 31.642174829154772
# 在第965步，我得到了一个更好的Loss:97.77708520464141，此时此刻，我的K和B是-1.32234798784317, 31.640580190348544
# 在第966步，我得到了一个更好的Loss:97.77447964524471，此时此刻，我的K和B是-1.3220973085667975, 31.638985589888957
# 在第967步，我得到了一个更好的Loss:97.77187421115944，此时此刻，我的K和B是-1.3218466353185663, 31.637391027775088
# 在第968步，我得到了一个更好的Loss:97.76926890237962，此时此刻，我的K和B是-1.3215959680983314, 31.635796504006017
# 在第969步，我得到了一个更好的Loss:97.76666371889917，此时此刻，我的K和B是-1.3213453069059478, 31.63420201858082
# 在第970步，我得到了一个更好的Loss:97.76405866071211，此时此刻，我的K和B是-1.3210946517412707, 31.63260757149857
# 在第971步，我得到了一个更好的Loss:97.76145372781234，此时此刻，我的K和B是-1.320844002604155, 31.631013162758354
# 在第972步，我得到了一个更好的Loss:97.75884892019394，此时此刻，我的K和B是-1.3205933594944559, 31.629418792359246
# 在第973步，我得到了一个更好的Loss:97.75624423785082，此时此刻，我的K和B是-1.3203427224120283, 31.627824460300324
# 在第974步，我得到了一个更好的Loss:97.75363968077696，此时此刻，我的K和B是-1.3200920913567276, 31.626230166580665
# 在第975步，我得到了一个更好的Loss:97.75103524896632，此时此刻，我的K和B是-1.3198414663284086, 31.62463591119935
# 在第976步，我得到了一个更好的Loss:97.74843094241294，此时此刻，我的K和B是-1.3195908473269262, 31.62304169415545
# 在第977步，我得到了一个更好的Loss:97.7458267611107，此时此刻，我的K和B是-1.3193402343521359, 31.62144751544805
# 在第978步，我得到了一个更好的Loss:97.74322270505367，此时此刻，我的K和B是-1.3190896274038924, 31.61985337507623
# 在第979步，我得到了一个更好的Loss:97.74061877423577，此时此刻，我的K和B是-1.3188390264820509, 31.61825927303906
# 在第980步，我得到了一个更好的Loss:97.738014968651，此时此刻，我的K和B是-1.3185884315864664, 31.616665209335626
# 在第981步，我得到了一个更好的Loss:97.73541128829332，此时此刻，我的K和B是-1.3183378427169943, 31.615071183965
# 在第982步，我得到了一个更好的Loss:97.73280773315672，此时此刻，我的K和B是-1.3180872598734894, 31.613477196926265
# 在第983步，我得到了一个更好的Loss:97.73020430323518，此时此刻，我的K和B是-1.3178366830558068, 31.611883248218497
# 在第984步，我得到了一个更好的Loss:97.72760099852268，此时此刻，我的K和B是-1.3175861122638017, 31.610289337840772
# 在第985步，我得到了一个更好的Loss:97.72499781901317，此时此刻，我的K和B是-1.3173355474973292, 31.608695465792174
# 在第986步，我得到了一个更好的Loss:97.72239476470064，此时此刻，我的K和B是-1.3170849887562444, 31.607101632071775
# 在第987步，我得到了一个更好的Loss:97.71979183557909，此时此刻，我的K和B是-1.316834436040402, 31.605507836678658
# 在第988步，我得到了一个更好的Loss:97.71718903164249，此时此刻，我的K和B是-1.3165838893496578, 31.6039140796119
# 在第989步，我得到了一个更好的Loss:97.71458635288481，此时此刻，我的K和B是-1.3163333486838664, 31.60232036087058
# 在第990步，我得到了一个更好的Loss:97.71198379930003，此时此刻，我的K和B是-1.3160828140428833, 31.60072668045377
# 在第991步，我得到了一个更好的Loss:97.70938137088216，此时此刻，我的K和B是-1.3158322854265634, 31.59913303836056
# 在第992步，我得到了一个更好的Loss:97.70677906762513，此时此刻，我的K和B是-1.3155817628347617, 31.59753943459002
# 在第993步，我得到了一个更好的Loss:97.70417688952294，此时此刻，我的K和B是-1.3153312462673337, 31.59594586914123
# 在第994步，我得到了一个更好的Loss:97.70157483656959，此时此刻，我的K和B是-1.315080735724134, 31.594352342013266
# 在第995步，我得到了一个更好的Loss:97.69897290875906，此时此刻，我的K和B是-1.3148302312050182, 31.59275885320521
# 在第996步，我得到了一个更好的Loss:97.69637110608532，此时此刻，我的K和B是-1.3145797327098412, 31.591165402716143
# 在第997步，我得到了一个更好的Loss:97.69376942854232，此时此刻，我的K和B是-1.3143292402384583, 31.58957199054514
# 在第998步，我得到了一个更好的Loss:97.6911678761241，此时此刻，我的K和B是-1.3140787537907246, 31.587978616691277
# 在第999步，我得到了一个更好的Loss:97.68856644882462，此时此刻，我的K和B是-1.313828273366495, 31.58638528115364

# %%
plt.scatter(k_history, b_history)

# %%
plt.scatter(X_rm, Y)
plt.scatter(X_rm, best_k * X_rm + best_b)

# %% [markdown]
# - KNN模型的原理和方法以及优势和劣势
# - Salient Feature 显著特征
# - Principle Components主成分
# - Correlation相关性
# - Loss函数
# - 随机模拟的方法来获得更优的值（蒙特卡洛模拟）
# - 随机模拟的缺点
# - 梯度下降
# - 模拟任意的直线了
# - 模拟更加复杂的曲线？？
